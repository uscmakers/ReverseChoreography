# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import LinearSVR
from sklearn.multioutput import MultiOutputRegressor
from sklearn.linear_model import Ridge
from sklearn.linear_model import ElasticNet
from sklearn.linear_model import Lasso
from sklearn.linear_model import BayesianRidge
from sklearn.linear_model import MultiTaskLasso
from sklearn.linear_model import MultiTaskElasticNet
from sklearn.ensemble import AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.feature_selection import RFECV
from sklearn.ensemble import RandomForestRegressor
from sklearn.feature_selection import SelectFromModel
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import SequentialFeatureSelector
import pickle

# %%
data = pd.read_csv("parser_output/extracted_features_split_3_28_upsample.csv")
data = data.dropna()

# %%
data
# Out:
#       Unnamed: 0  Unnamed: 0.1  LEFT_EYE_OUTER_POS_x__kurtosis  \
# 0              0      1.000000                       -0.500597
# 1              1      1.000000                       -0.483415
# 2              2      1.000000                       -1.564327
# 3              3      1.000000                        5.505027
# 4              4      1.000000                       -1.651266
# ...          ...           ...                             ...
# 2731        2731      1.009253                       -0.429160
# 2732        2732      1.007549                       -0.295804
# 2733        2733      1.007922                       -0.453641
# 2734        2734      1.002436                       -1.371323
# 2735        2735      1.002979                        0.073124
#
#       LEFT_EYE_OUTER_POS_x__standard_deviation  \
# 0                                    30.432529
# 1                                    27.503200
# 2                                    19.279543
# 3                                    13.406352
# 4                                    29.739429
# ...                                        ...
# 2731                                 23.699830
# 2732                                 26.620043
# 2733                                 38.225051
# 2734                                 37.603216
# 2735                                 31.811209
#
#       LEFT_EYE_OUTER_POS_x__autocorrelation__lag_10  \
# 0                                          0.473995
# 1                                          0.059756
# 2                                          0.591867
# 3                                          0.227827
# 4                                          0.529723
# ...                                             ...
# 2731                                       0.071023
# 2732                                       0.135026
# 2733                                       0.551654
# 2734                                       0.803757
# 2735                                       0.157222
#
#       LEFT_EYE_OUTER_POS_x__approximate_entropy__m_20__r_0.05  \
# 0                                              0.019048
# 1                                              0.019418
# 2                                              0.019418
# 3                                              0.017700
# 4                                              0.017700
# ...                                                 ...
# 2731                                           0.024342
# 2732                                           0.023765
# 2733                                           0.021456
# 2734                                           0.024938
# 2735                                           0.017156
#
#       LEFT_EYE_OUTER_POS_x__c3__lag_10  \
# 0                         1.156625e+07
# 1                         1.235949e+07
# 2                         8.488430e+06
# 3                         1.841696e+07
# 4                         9.677430e+06
# ...                                ...
# 2731                      2.881071e+07
# 2732                      2.151611e+07
# 2733                      1.693204e+07
# 2734                      2.479525e+07
# 2735                      3.446335e+07
#
#       LEFT_EYE_OUTER_POS_x__cid_ce__normalize_True  \
# 0                                         1.356488
# 1                                         2.453771
# 2                                         1.356007
# 3                                         4.185149
# 4                                         1.264870
# ...                                            ...
# 2731                                      3.200530
# 2732                                      2.511810
# 2733                                      1.299832
# 2734                                      1.333436
# 2735                                      2.112359
#
#       LEFT_EYE_OUTER_POS_y__kurtosis  \
# 0                           0.947163
# 1                           5.098091
# 2                          -1.310822
# 3                          -0.679397
# 4                          -0.672379
# ...                              ...
# 2731                        4.065613
# 2732                       -0.992072
# 2733                        2.911378
# 2734                       -0.302217
# 2735                       -0.279968
#
#       LEFT_EYE_OUTER_POS_y__standard_deviation  ...       key   loudness  \
# 0                                    32.875727  ...  1.000000 -11.683000
# 1                                    42.493897  ...  1.000000 -11.683000
# 2                                    37.907508  ...  1.000000 -11.683000
# 3                                    14.547386  ...  1.000000  -4.961000
# 4                                    22.561584  ...  1.000000  -4.961000
# ...                                        ...  ...       ...        ...
# 2731                                 26.700536  ...  1.001468  -8.044790
# 2732                                 14.717245  ...  1.009341  -8.044112
# 2733                                 22.203969  ...  2.005843  -2.717820
# 2734                                 19.361277  ...  2.006492  -2.708844
# 2735                                 14.610880  ...  2.004956  -2.716299
#
#           mode  speechiness  acousticness  instrumentalness  liveness  \
# 0     1.000000     0.471000      0.034600          0.069800  0.112000
# 1     1.000000     0.471000      0.034600          0.069800  0.112000
# 2     1.000000     0.471000      0.034600          0.069800  0.112000
# 3     1.000000     0.040600      0.013000          0.000000  0.094400
# 4     1.000000     0.040600      0.013000          0.000000  0.094400
# ...        ...          ...           ...               ...       ...
# 2731  0.009961     0.064800      0.437464          0.001176  0.119714
# 2732  0.009960     0.063448      0.440401          0.000517  0.114702
# 2733  0.007675     0.149796      0.102007          0.001369  0.295883
# 2734  0.002764     0.146745      0.107539          0.002919  0.293654
# 2735  0.002322     0.151568      0.102394          0.005549  0.291190
#
#        valence       tempo  time_signature
# 0     0.394000  120.461000        4.000000
# 1     0.394000  120.461000        4.000000
# 2     0.394000  120.461000        4.000000
# 3     0.860000  134.066000        4.000000
# 4     0.860000  134.066000        4.000000
# ...        ...         ...             ...
# 2731  0.321766  110.022306        4.006691
# 2732  0.324953  110.021905        4.003841
# 2733  0.714539  120.035184        4.004975
# 2734  0.715673  120.029463        4.006945
# 2735  0.721275  120.035093        4.003433
#
# [2502 rows x 350 columns]

# %%
#LOOK INTO https://scikit-learn.org/stable/modules/classes.html#module-sklearn.feature_selection
#multi output regressor? - https://scikit-learn.org/stable/modules/generated/sklearn.multioutput.MultiOutputRegressor.html#sklearn.multioutput.MultiOutputRegressor

# %%
y = data[['danceability', 'energy', 'loudness', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo']]
x = data[data.columns[1:len(data.columns)-12]]

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.7)
X_train = X_train.iloc[: , 1:]
X_test = X_test.iloc[: , 1:]

# %%
X_train
# Out:
#       LEFT_EYE_OUTER_POS_x__kurtosis  \
# 1808                       -0.732713
# 1789                       -0.896652
# 369                        -1.110663
# 1567                       -1.446217
# 1417                       -1.050816
# ...                              ...
# 1792                       -1.454353
# 598                        -1.365126
# 453                        -0.456614
# 2171                       -1.632134
# 1736                       -1.500603
#
#       LEFT_EYE_OUTER_POS_x__standard_deviation  \
# 1808                                 28.194820
# 1789                                 29.611799
# 369                                  24.563256
# 1567                                 20.822549
# 1417                                 20.814251
# ...                                        ...
# 1792                                 33.360772
# 598                                  13.279152
# 453                                  38.224373
# 2171                                 17.900589
# 1736                                 19.305112
#
#       LEFT_EYE_OUTER_POS_x__autocorrelation__lag_10  \
# 1808                                       0.628000
# 1789                                       0.340777
# 369                                       -0.067366
# 1567                                       0.719783
# 1417                                       0.323304
# ...                                             ...
# 1792                                       0.726833
# 598                                       -0.271034
# 453                                        0.547324
# 2171                                      -0.153196
# 1736                                       0.112362
#
#       LEFT_EYE_OUTER_POS_x__approximate_entropy__m_20__r_0.05  \
# 1808                                           0.022466
# 1789                                           0.027690
# 369                                            0.018349
# 1567                                           0.029762
# 1417                                           0.020264
# ...                                                 ...
# 1792                                           0.016747
# 598                                            0.032908
# 453                                            0.015038
# 2171                                           0.031868
# 1736                                           0.029091
#
#       LEFT_EYE_OUTER_POS_x__c3__lag_10  \
# 1808                      1.578121e+07
# 1789                      3.018523e+07
# 369                       1.485840e+07
# 1567                      5.419831e+06
# 1417                      1.112642e+07
# ...                                ...
# 1792                      4.220965e+07
# 598                       1.103708e+07
# 453                       1.693204e+07
# 2171                      1.635314e+07
# 1736                      1.447744e+07
#
#       LEFT_EYE_OUTER_POS_x__cid_ce__normalize_True  \
# 1808                                      2.034556
# 1789                                      1.778194
# 369                                       1.631727
# 1567                                      0.935294
# 1417                                      2.257428
# ...                                            ...
# 1792                                      1.783238
# 598                                       2.697623
# 453                                       1.295994
# 2171                                      1.731752
# 1736                                      1.837867
#
#       LEFT_EYE_OUTER_POS_y__kurtosis  \
# 1808                       -0.593628
# 1789                       -0.554461
# 369                        -1.389227
# 1567                       -0.089759
# 1417                       -1.464225
# ...                              ...
# 1792                        0.256750
# 598                         0.123548
# 453                         2.908597
# 2171                       -1.217520
# 1736                       -0.775231
#
#       LEFT_EYE_OUTER_POS_y__standard_deviation  \
# 1808                                 13.778635
# 1789                                 16.015270
# 369                                   5.146098
# 1567                                  3.899744
# 1417                                 81.081338
# ...                                        ...
# 1792                                 24.864898
# 598                                  10.578151
# 453                                  22.198391
# 2171                                  3.260174
# 1736                                 19.078478
#
#       LEFT_EYE_OUTER_POS_y__autocorrelation__lag_10  \
# 1808                                       0.003547
# 1789                                       0.129206
# 369                                        0.178898
# 1567                                       0.004365
# 1417                                       0.755883
# ...                                             ...
# 1792                                      -0.058093
# 598                                       -0.125109
# 453                                        0.160988
# 2171                                      -0.047846
# 1736                                       0.272555
#
#       LEFT_EYE_OUTER_POS_y__approximate_entropy__m_20__r_0.05  ...  \
# 1808                                           0.013996        ...
# 1789                                           0.024086        ...
# 369                                            0.018349        ...
# 1567                                           0.028516        ...
# 1417                                           0.016498        ...
# ...                                                 ...        ...
# 1792                                           0.017208        ...
# 598                                            0.033485        ...
# 453                                            0.015038        ...
# 2171                                           0.022666        ...
# 1736                                           0.032037        ...
#
#       RIGHT_ANKLE_DIST_x__autocorrelation__lag_10  \
# 1808                                    -0.069195
# 1789                                     0.009473
# 369                                      0.009880
# 1567                                     0.078619
# 1417                                     0.026612
# ...                                           ...
# 1792                                     0.069385
# 598                                      0.035819
# 453                                     -0.089709
# 2171                                     0.002383
# 1736                                    -0.054382
#
#       RIGHT_ANKLE_DIST_x__approximate_entropy__m_20__r_0.05  \
# 1808                                           0.017264
# 1789                                           0.029516
# 369                                            0.018349
# 1567                                           0.028887
# 1417                                           0.018037
# ...                                                 ...
# 1792                                           0.023448
# 598                                            0.032336
# 453                                            0.015038
# 2171                                           0.025446
# 1736                                           0.029673
#
#       RIGHT_ANKLE_DIST_x__c3__lag_10  \
# 1808                       -0.079437
# 1789                       -0.065908
# 369                        -0.072201
# 1567                       -0.160390
# 1417                        2.940728
# ...                              ...
# 1792                       -2.680787
# 598                        -0.254723
# 453                      -119.589493
# 2171                        0.600564
# 1736                        0.537728
#
#       RIGHT_ANKLE_DIST_x__cid_ce__normalize_True  \
# 1808                                   13.973063
# 1789                                    7.230666
# 369                                    10.504360
# 1567                                    6.004460
# 1417                                   12.970415
# ...                                          ...
# 1792                                   10.253197
# 598                                     8.505356
# 453                                    10.997688
# 2171                                   10.032275
# 1736                                    6.150624
#
#       RIGHT_ANKLE_DIST_y__kurtosis  RIGHT_ANKLE_DIST_y__standard_deviation  \
# 1808                     12.553279                                1.600038
# 1789                     20.476355                                6.567641
# 369                       3.450735                                1.999150
# 1567                     20.190094                                1.549247
# 1417                     20.972681                                5.657273
# ...                            ...                                     ...
# 1792                     34.421457                                4.536553
# 598                       1.145599                                2.776447
# 453                      28.727636                                9.223290
# 2171                      9.250274                                3.494834
# 1736                      6.167920                                1.915151
#
#       RIGHT_ANKLE_DIST_y__autocorrelation__lag_10  \
# 1808                                    -0.042663
# 1789                                    -0.021048
# 369                                     -0.064851
# 1567                                    -0.208347
# 1417                                     0.071497
# ...                                           ...
# 1792                                     0.126449
# 598                                      0.028192
# 453                                     -0.067404
# 2171                                    -0.011543
# 1736                                    -0.001922
#
#       RIGHT_ANKLE_DIST_y__approximate_entropy__m_20__r_0.05  \
# 1808                                           0.014808
# 1789                                           0.025918
# 369                                            0.018349
# 1567                                           0.026540
# 1417                                           0.018909
# ...                                                 ...
# 1792                                           0.024253
# 598                                            0.023907
# 453                                            0.015038
# 2171                                           0.031151
# 1736                                           0.027089
#
#       RIGHT_ANKLE_DIST_y__c3__lag_10  \
# 1808                        0.128666
# 1789                        0.207310
# 369                         0.065081
# 1567                        0.174581
# 1417                       -0.440608
# ...                              ...
# 1792                       -5.710497
# 598                        -0.202284
# 453                        28.186397
# 2171                       -0.550470
# 1736                        0.200557
#
#       RIGHT_ANKLE_DIST_y__cid_ce__normalize_True
# 1808                                   13.534631
# 1789                                   10.375145
# 369                                    11.745526
# 1567                                    8.886813
# 1417                                   12.920679
# ...                                          ...
# 1792                                   14.079555
# 598                                    10.668974
# 453                                    12.992763
# 2171                                   10.632440
# 1736                                    9.268083
#
# [750 rows x 336 columns]

# %% [markdown]
# ## REGRESSION MODELS

# %%
#lINEAR REGRESSION - 
reg_model = LinearRegression().fit(X_train, y_train)
ypred_train = reg_model.predict(X_train)
ypred_test = reg_model.predict(X_test)
print("LINEAR REGRESSION")
print("Train Score: ")
print(r2_score(y_train, ypred_train))
print("Test Score: ")
print(r2_score(y_test, ypred_test))
# Out:
# LINEAR REGRESSION
# Train Score:
# 0.8796130882293479
# Test Score:
# -0.5451810214812262

# %%
reg_model.coef_
# Out:
# array([[ 1.28813971e-02, -3.36631733e-02, -3.08538058e-02, ...,
#          1.16958098e+00, -4.88009759e-04, -2.36270322e-02],
#        [-9.59259194e-02,  6.76114715e-02, -7.53776705e-01, ...,
#         -1.14427597e-01, -3.69118347e-04, -1.65800850e-02],
#        [-1.78370165e+00,  1.31254187e+00, -3.62814228e+00, ...,
#          7.64101748e+00, -8.06920817e-04, -3.79247869e-01],
#        ...,
#        [-9.11276152e-03, -1.41367126e-02, -2.10185392e-01, ...,
#          1.19413825e-01, -4.86758720e-04,  4.06309500e-03],
#        [-4.34336971e-02,  2.87508988e-02,  2.71900138e-02, ...,
#          1.17096007e+00, -7.60265461e-04, -5.18011899e-02],
#        [-5.07927347e+00,  6.06587997e+00,  8.27208341e+01, ...,
#          7.18792858e+01,  6.52895951e-02, -1.84124091e+00]])

# %%
#K NEIGHBORS REGRESSOR - https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsRegressor.html#sklearn.neighbors.KNeighborsRegressor
knn_model = KNeighborsRegressor().fit(X_train, y_train)
ypred_train = knn_model.predict(X_train)
ypred_test = knn_model.predict(X_test)
print("KNN REGRESSION")
print("Train Score: ")
print(r2_score(y_train, ypred_train))
print("Test Score: ")
print(r2_score(y_test, ypred_test))
# Out:
# KNN REGRESSION
# Train Score:
# 0.6162084583920601
# Test Score:
# 0.28509922065957816

# %%
#LINEAR SVR - https://scikit-learn.org/stable/modules/generated/sklearn.svm.LinearSVR.html#sklearn.svm.LinearSVR
svr_model = MultiOutputRegressor(LinearSVR()).fit(X_train, y_train)
ypred_train = svr_model.predict(X_train)
ypred_test = svr_model.predict(X_test)
print("SVR REGRESSION")
print("Train Score: ")
print(r2_score(y_train, ypred_train))
print("Test Score: ")
print(r2_score(y_test, ypred_test))
# Out:
# C:\Users\mbase\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\mbase\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\mbase\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\mbase\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\mbase\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\mbase\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\mbase\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\mbase\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# SVR REGRESSION
# Train Score:
# -8.849588350709274
# Test Score:
# -8.742900996010695
# C:\Users\mbase\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(

# %%
#RIDGE REGRESSOR - https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.Ridge.html#sklearn.linear_model.Ridge
ridge_model = Ridge().fit(X_train, y_train)
ypred_train = ridge_model.predict(X_train)
ypred_test = ridge_model.predict(X_test)
print("RIDGE REGRESSION")
print("Train Score: ")
print(r2_score(y_train, ypred_train))
print("Test Score: ")
print(r2_score(y_test, ypred_test))
# Out:
# RIDGE REGRESSION
# Train Score:
# 0.835342256354502
# Test Score:
# -0.08134606454770814
# C:\Users\mbase\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:156: LinAlgWarning: Ill-conditioned matrix (rcond=2.53411e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T

# %%
#ELASTIC NET - https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.ElasticNet.html#sklearn.linear_model.ElasticNet
elastic_model = ElasticNet().fit(X_train, y_train)
ypred_train = elastic_model.predict(X_train)
ypred_test = elastic_model.predict(X_test)
print("ELASTIC REGRESSION")
print("Train Score: ")
print(r2_score(y_train, ypred_train))
print("Test Score: ")
print(r2_score(y_test, ypred_test))
# Out:
# C:\Users\mbase\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.939e+00, tolerance: 1.396e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\mbase\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.250e+01, tolerance: 2.856e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\mbase\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.389e+03, tolerance: 6.379e-01
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\mbase\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.560e+00, tolerance: 1.851e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\mbase\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.378e+01, tolerance: 3.124e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\mbase\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.668e-01, tolerance: 6.110e-05
#   model = cd_fast.enet_coordinate_descent(
# ELASTIC REGRESSION
# Train Score:
# 0.22106337432485543
# Test Score:
# 0.10054467361903041
# C:\Users\mbase\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.812e+00, tolerance: 6.311e-04
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\mbase\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.805e+01, tolerance: 4.250e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\mbase\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.139e+05, tolerance: 4.296e+01
#   model = cd_fast.enet_coordinate_descent(

# %%
#LASSO - https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.Lasso.html#sklearn.linear_model.Lasso
lasso_model = Lasso().fit(X_train, y_train)
ypred_train = lasso_model.predict(X_train)
ypred_test = lasso_model.predict(X_test)
print("LASSO REGRESSION")
print("Train Score: ")
print(r2_score(y_train, ypred_train))
print("Test Score: ")
print(r2_score(y_test, ypred_test))
# Out:
# C:\Users\mbase\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.033e+00, tolerance: 1.396e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\mbase\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.261e+01, tolerance: 2.856e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\mbase\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.584e+03, tolerance: 6.379e-01
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\mbase\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.669e+00, tolerance: 1.851e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\mbase\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.384e+01, tolerance: 3.124e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\mbase\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.680e-01, tolerance: 6.110e-05
#   model = cd_fast.enet_coordinate_descent(
# LASSO REGRESSION
# Train Score:
# 0.19712616851343043
# Test Score:
# 0.09686022990460096
# C:\Users\mbase\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.838e+00, tolerance: 6.311e-04
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\mbase\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.830e+01, tolerance: 4.250e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\mbase\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.223e+05, tolerance: 4.296e+01
#   model = cd_fast.enet_coordinate_descent(

# %%
#Bayesian Ridge Regression? https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.BayesianRidge.html#sklearn.linear_model.BayesianRidge
bayesianRidge_model = MultiOutputRegressor(BayesianRidge()).fit(X_train, y_train)
ypred_train = bayesianRidge_model.predict(X_train)
ypred_test = bayesianRidge_model.predict(X_test)
print("BAYESIAN RIDGE REGRESSION")
print("Train Score: ")
print(r2_score(y_train, ypred_train))
print("Test Score: ")
print(r2_score(y_test, ypred_test))
# Out:
# BAYESIAN RIDGE REGRESSION
# Train Score:
# 0.2713037941249488
# Test Score:
# 0.10433929190171126

# %%
#Multitask Lasso? https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.MultiTaskLasso.html#sklearn.linear_model.MultiTaskLasso
mtLasso_model = MultiTaskLasso().fit(X_train, y_train)
ypred_train = mtLasso_model.predict(X_train)
ypred_test = mtLasso_model.predict(X_test)
print("MULTITASK LASSO REGRESSION")
print("Train Score: ")
print(r2_score(y_train, ypred_train))
print("Test Score: ")
print(r2_score(y_test, ypred_test))
# Out:
# MULTITASK LASSO REGRESSION
# Train Score:
# 0.4387705735118473
# Test Score:
# 0.1968021524222459
# C:\Users\mbase\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:2442: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 124359.89253239841, tolerance: 43.607160155574825
#   ) = cd_fast.enet_coordinate_descent_multi_task(

# %%
#Multitask Elastic Net? https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.MultiTaskElasticNet.html#sklearn.linear_model.MultiTaskElasticNet
mtNet_model = MultiTaskElasticNet().fit(X_train, y_train)
ypred_train = mtNet_model.predict(X_train)
ypred_test = mtNet_model.predict(X_test)
print("MULTITASK ELASTIC NET REGRESSION")
print("Train Score: ")
print(r2_score(y_train, ypred_train))
print("Test Score: ")
print(r2_score(y_test, ypred_test))
# Out:
# MULTITASK ELASTIC NET REGRESSION
# Train Score:
# 0.4961524960940811
# Test Score:
# 0.2247680147249718
# C:\Users\mbase\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:2442: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 115721.66547454064, tolerance: 43.607160155574825
#   ) = cd_fast.enet_coordinate_descent_multi_task(

# %%
#AdaBoost - https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.AdaBoostRegressor.html#sklearn.ensemble.AdaBoostRegressor
adaBoost_model = MultiOutputRegressor(AdaBoostRegressor()).fit(X_train, y_train)
ypred_train = adaBoost_model.predict(X_train)
ypred_test = adaBoost_model.predict(X_test)
print("ADABOOST REGRESSION")
print("Train Score: ")
print(r2_score(y_train, ypred_train))
print("Test Score: ")
print(r2_score(y_test, ypred_test))
# Out:
# ADABOOST REGRESSION
# Train Score:
# 0.6535481623370141
# Test Score:
# 0.49680016925242193

# %%
#Tree - https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeRegressor.html#sklearn.tree.DecisionTreeRegressor
tree_model = DecisionTreeRegressor().fit(X_train, y_train)
ypred_train = tree_model.predict(X_train)
ypred_test = tree_model.predict(X_test)
print("TREE REGRESSION")
print("Train Score: ")
print(r2_score(y_train, ypred_train))
print("Test Score: ")
print(r2_score(y_test, ypred_test))
# Out:
# TREE REGRESSION
# Train Score:
# 1.0
# Test Score:
# 0.5612278064556763

# %%
#Random Forest - https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestRegressor.html#sklearn.ensemble.RandomForestRegressor
rf_model = RandomForestRegressor().fit(X_train, y_train)
ypred_train = rf_model.predict(X_train)
ypred_test = rf_model.predict(X_test)
print("RANDOM FOREST REGRESSION")
print("Train Score: ")
print(r2_score(y_train, ypred_train))
print("Test Score: ")
print(r2_score(y_test, ypred_test))
# Out:
# RANDOM FOREST REGRESSION
# Train Score:
# 0.9703686749911827
# Test Score:
# 0.7601347484931468

# %% [markdown]
# # Model Export

# %%
filename = 'tempModel.sav'
pickle.dump(rf_model, open(filename, 'wb'))

# %% [markdown]
# # Feature Selection

# %%
selected_linreg = RFECV(reg_model, step = 10, cv = 5)
selected_linreg = selected_linreg.fit(X_train, y_train)
# Out:
# C:\Users\mbase\anaconda3\lib\site-packages\sklearn\base.py:445: UserWarning: X does not have valid feature names, but RFECV was fitted with feature names
#   warnings.warn(

# %%
selected_RF = RFECV(rf_model, step=25, cv=5)
selected_RF = selected_RF.fit(X_train, y_train)
ypred_train = selected_RF.predict(X_train)
ypred_test = selected_RF.predict(X_test)
print("RANDOM FOREST REGRESSION - SELECTED FEATURES")
print("Train Score: ")
print(r2_score(y_train, ypred_train))
print("Test Score: ")
print(r2_score(y_test, ypred_test))
# Out:
# C:\Users\mbase\anaconda3\lib\site-packages\sklearn\base.py:445: UserWarning: X does not have valid feature names, but RFECV was fitted with feature names
#   warnings.warn(
# RANDOM FOREST REGRESSION - SELECTED FEATURES
# Train Score:
# 0.9726972022454492
# Test Score:
# 0.7684743277005949

# %%
names = pd.DataFrame(selected_RF.feature_names_in_)
best_features = [names.iloc[selected_RF.ranking_==1]]
best_features
# Out:
# [                                                     0
#  0                       LEFT_EYE_OUTER_POS_x__kurtosis
#  2        LEFT_EYE_OUTER_POS_x__autocorrelation__lag_10
#  3    LEFT_EYE_OUTER_POS_x__approximate_entropy__m_2...
#  5         LEFT_EYE_OUTER_POS_x__cid_ce__normalize_True
#  6                       LEFT_EYE_OUTER_POS_y__kurtosis
#  ..                                                 ...
#  329         RIGHT_ANKLE_DIST_x__cid_ce__normalize_True
#  330                       RIGHT_ANKLE_DIST_y__kurtosis
#  332        RIGHT_ANKLE_DIST_y__autocorrelation__lag_10
#  334                     RIGHT_ANKLE_DIST_y__c3__lag_10
#  335         RIGHT_ANKLE_DIST_y__cid_ce__normalize_True
#
#  [211 rows x 1 columns]]
