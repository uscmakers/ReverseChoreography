# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import LinearSVR
from sklearn.multioutput import MultiOutputRegressor
from sklearn.linear_model import Ridge
from sklearn.linear_model import ElasticNet
from sklearn.linear_model import Lasso
from sklearn.linear_model import BayesianRidge
from sklearn.linear_model import MultiTaskLasso
from sklearn.linear_model import MultiTaskElasticNet
from sklearn.ensemble import AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.feature_selection import RFECV
from sklearn.ensemble import RandomForestRegressor
from sklearn.feature_selection import SelectFromModel
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import SequentialFeatureSelector
import pickle

# %%
data = pd.read_csv("parser_output/extracted_features_split_3_28_upsample.csv")
data = data.dropna()

# %%
data
# Out:
#       Unnamed: 0  Unnamed: 0.1  LEFT_EYE_OUTER_POS_x__kurtosis  \
# 0              0      1.000000                       -0.500597
# 1              1      1.000000                       -0.483415
# 2              2      1.000000                       -1.564327
# 3              3      1.000000                        5.505027
# 4              4      1.000000                       -1.651266
# ...          ...           ...                             ...
# 2731        2731      1.009253                       -0.429160
# 2732        2732      1.007549                       -0.295804
# 2733        2733      1.007922                       -0.453641
# 2734        2734      1.002436                       -1.371323
# 2735        2735      1.002979                        0.073124
#
#       LEFT_EYE_OUTER_POS_x__standard_deviation  \
# 0                                    30.432529
# 1                                    27.503200
# 2                                    19.279543
# 3                                    13.406352
# 4                                    29.739429
# ...                                        ...
# 2731                                 23.699830
# 2732                                 26.620043
# 2733                                 38.225051
# 2734                                 37.603216
# 2735                                 31.811209
#
#       LEFT_EYE_OUTER_POS_x__autocorrelation__lag_10  \
# 0                                          0.473995
# 1                                          0.059756
# 2                                          0.591867
# 3                                          0.227827
# 4                                          0.529723
# ...                                             ...
# 2731                                       0.071023
# 2732                                       0.135026
# 2733                                       0.551654
# 2734                                       0.803757
# 2735                                       0.157222
#
#       LEFT_EYE_OUTER_POS_x__approximate_entropy__m_20__r_0.05  \
# 0                                              0.019048
# 1                                              0.019418
# 2                                              0.019418
# 3                                              0.017700
# 4                                              0.017700
# ...                                                 ...
# 2731                                           0.024342
# 2732                                           0.023765
# 2733                                           0.021456
# 2734                                           0.024938
# 2735                                           0.017156
#
#       LEFT_EYE_OUTER_POS_x__c3__lag_10  \
# 0                         1.156625e+07
# 1                         1.235949e+07
# 2                         8.488430e+06
# 3                         1.841696e+07
# 4                         9.677430e+06
# ...                                ...
# 2731                      2.881071e+07
# 2732                      2.151611e+07
# 2733                      1.693204e+07
# 2734                      2.479525e+07
# 2735                      3.446335e+07
#
#       LEFT_EYE_OUTER_POS_x__cid_ce__normalize_True  \
# 0                                         1.356488
# 1                                         2.453771
# 2                                         1.356007
# 3                                         4.185149
# 4                                         1.264870
# ...                                            ...
# 2731                                      3.200530
# 2732                                      2.511810
# 2733                                      1.299832
# 2734                                      1.333436
# 2735                                      2.112359
#
#       LEFT_EYE_OUTER_POS_y__kurtosis  \
# 0                           0.947163
# 1                           5.098091
# 2                          -1.310822
# 3                          -0.679397
# 4                          -0.672379
# ...                              ...
# 2731                        4.065613
# 2732                       -0.992072
# 2733                        2.911378
# 2734                       -0.302217
# 2735                       -0.279968
#
#       LEFT_EYE_OUTER_POS_y__standard_deviation  ...       key   loudness  \
# 0                                    32.875727  ...  1.000000 -11.683000
# 1                                    42.493897  ...  1.000000 -11.683000
# 2                                    37.907508  ...  1.000000 -11.683000
# 3                                    14.547386  ...  1.000000  -4.961000
# 4                                    22.561584  ...  1.000000  -4.961000
# ...                                        ...  ...       ...        ...
# 2731                                 26.700536  ...  1.001468  -8.044790
# 2732                                 14.717245  ...  1.009341  -8.044112
# 2733                                 22.203969  ...  2.005843  -2.717820
# 2734                                 19.361277  ...  2.006492  -2.708844
# 2735                                 14.610880  ...  2.004956  -2.716299
#
#           mode  speechiness  acousticness  instrumentalness  liveness  \
# 0     1.000000     0.471000      0.034600          0.069800  0.112000
# 1     1.000000     0.471000      0.034600          0.069800  0.112000
# 2     1.000000     0.471000      0.034600          0.069800  0.112000
# 3     1.000000     0.040600      0.013000          0.000000  0.094400
# 4     1.000000     0.040600      0.013000          0.000000  0.094400
# ...        ...          ...           ...               ...       ...
# 2731  0.009961     0.064800      0.437464          0.001176  0.119714
# 2732  0.009960     0.063448      0.440401          0.000517  0.114702
# 2733  0.007675     0.149796      0.102007          0.001369  0.295883
# 2734  0.002764     0.146745      0.107539          0.002919  0.293654
# 2735  0.002322     0.151568      0.102394          0.005549  0.291190
#
#        valence       tempo  time_signature
# 0     0.394000  120.461000        4.000000
# 1     0.394000  120.461000        4.000000
# 2     0.394000  120.461000        4.000000
# 3     0.860000  134.066000        4.000000
# 4     0.860000  134.066000        4.000000
# ...        ...         ...             ...
# 2731  0.321766  110.022306        4.006691
# 2732  0.324953  110.021905        4.003841
# 2733  0.714539  120.035184        4.004975
# 2734  0.715673  120.029463        4.006945
# 2735  0.721275  120.035093        4.003433
#
# [2502 rows x 350 columns]

# %%
#LOOK INTO https://scikit-learn.org/stable/modules/classes.html#module-sklearn.feature_selection
#multi output regressor? - https://scikit-learn.org/stable/modules/generated/sklearn.multioutput.MultiOutputRegressor.html#sklearn.multioutput.MultiOutputRegressor

# %%
y = data[['danceability', 'energy', 'loudness', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo']]
x = data[data.columns[1:len(data.columns)-12]]

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.7)
X_train = X_train.iloc[: , 1:]
X_test = X_test.iloc[: , 1:]

# %%
X_train
# Out:
#       LEFT_EYE_OUTER_POS_x__kurtosis  \
# 407                        -0.364724
# 962                        -1.277122
# 1171                       -1.427361
# 726                        -0.495156
# 354                        -0.495753
# ...                              ...
# 2068                        0.342863
# 1451                       -0.416879
# 2385                       -0.520849
# 1954                       -0.062474
# 2581                        2.344621
#
#       LEFT_EYE_OUTER_POS_x__standard_deviation  \
# 407                                  37.772131
# 962                                  24.393440
# 1171                                 29.741031
# 726                                   9.831541
# 354                                  14.318282
# ...                                        ...
# 2068                                 14.654032
# 1451                                 14.041002
# 2385                                 20.386573
# 1954                                 16.507010
# 2581                                 10.081599
#
#       LEFT_EYE_OUTER_POS_x__autocorrelation__lag_10  \
# 407                                        0.501628
# 962                                        0.613656
# 1171                                       0.371961
# 726                                       -0.151387
# 354                                       -0.019207
# ...                                             ...
# 2068                                      -0.090574
# 1451                                       0.402215
# 2385                                      -0.198502
# 1954                                      -0.068438
# 2581                                       0.127529
#
#       LEFT_EYE_OUTER_POS_x__approximate_entropy__m_20__r_0.05  \
# 407                                            0.015267
# 962                                            0.008778
# 1171                                           0.034006
# 726                                            0.034206
# 354                                            0.017392
# ...                                                 ...
# 2068                                           0.030962
# 1451                                           0.018669
# 2385                                           0.035427
# 1954                                           0.042010
# 2581                                           0.026649
#
#       LEFT_EYE_OUTER_POS_x__c3__lag_10  \
# 407                       2.578896e+07
# 962                       1.061907e+07
# 1171                      7.778172e+06
# 726                       2.079385e+07
# 354                       1.567061e+07
# ...                                ...
# 2068                      7.035436e+06
# 1451                      1.340155e+07
# 2385                      1.123871e+07
# 1954                      1.381274e+07
# 2581                      1.759730e+07
#
#       LEFT_EYE_OUTER_POS_x__cid_ce__normalize_True  \
# 407                                       1.525285
# 962                                       1.689754
# 1171                                      1.280082
# 726                                       2.913172
# 354                                       3.485270
# ...                                            ...
# 2068                                      2.736125
# 1451                                      2.310809
# 2385                                      1.778746
# 1954                                      2.607794
# 2581                                      2.213520
#
#       LEFT_EYE_OUTER_POS_y__kurtosis  \
# 407                         1.150819
# 962                        -1.079957
# 1171                       -0.322458
# 726                        -0.898757
# 354                         0.083819
# ...                              ...
# 2068                       -0.587995
# 1451                        6.087718
# 2385                       -0.527647
# 1954                       -1.058250
# 2581                        1.008039
#
#       LEFT_EYE_OUTER_POS_y__standard_deviation  \
# 407                                  14.403053
# 962                                  31.284803
# 1171                                  5.162748
# 726                                  10.455837
# 354                                  18.951193
# ...                                        ...
# 2068                                  7.094469
# 1451                                 36.662215
# 2385                                 21.024651
# 1954                                 10.222823
# 2581                                  9.738119
#
#       LEFT_EYE_OUTER_POS_y__autocorrelation__lag_10  \
# 407                                       -0.112518
# 962                                        0.560216
# 1171                                      -0.132532
# 726                                       -0.105640
# 354                                        0.496424
# ...                                             ...
# 2068                                      -0.475084
# 1451                                      -0.117492
# 2385                                       0.396233
# 1954                                      -0.097811
# 2581                                      -0.187421
#
#       LEFT_EYE_OUTER_POS_y__approximate_entropy__m_20__r_0.05  ...  \
# 407                                            0.015267        ...
# 962                                            0.023015        ...
# 1171                                           0.039960        ...
# 726                                            0.033118        ...
# 354                                            0.017392        ...
# ...                                                 ...        ...
# 2068                                           0.033821        ...
# 1451                                           0.023918        ...
# 2385                                           0.041887        ...
# 1954                                           0.039029        ...
# 2581                                           0.024109        ...
#
#       RIGHT_ANKLE_DIST_x__autocorrelation__lag_10  \
# 407                                     -0.282859
# 962                                     -0.221812
# 1171                                    -0.039380
# 726                                     -0.207419
# 354                                     -0.184524
# ...                                           ...
# 2068                                    -0.003201
# 1451                                     0.099279
# 2385                                     0.034868
# 1954                                     0.044653
# 2581                                     0.096325
#
#       RIGHT_ANKLE_DIST_x__approximate_entropy__m_20__r_0.05  \
# 407                                            0.015267
# 962                                            0.024341
# 1171                                           0.033592
# 726                                            0.036357
# 354                                            0.017392
# ...                                                 ...
# 2068                                           0.036252
# 1451                                           0.019826
# 2385                                           0.034480
# 1954                                           0.044696
# 2581                                           0.019278
#
#       RIGHT_ANKLE_DIST_x__c3__lag_10  \
# 407                        15.727955
# 962                        -0.231474
# 1171                     -752.303954
# 726                      -179.023460
# 354                         5.137976
# ...                              ...
# 2068                        5.284749
# 1451                        4.211161
# 2385                     -120.119812
# 1954                        2.779467
# 2581                        5.113349
#
#       RIGHT_ANKLE_DIST_x__cid_ce__normalize_True  \
# 407                                     6.341744
# 962                                    13.344481
# 1171                                    8.246598
# 726                                     7.925319
# 354                                    10.212220
# ...                                          ...
# 2068                                    7.820192
# 1451                                   12.046051
# 2385                                    7.514904
# 1954                                    9.689766
# 2581                                    8.917232
#
#       RIGHT_ANKLE_DIST_y__kurtosis  RIGHT_ANKLE_DIST_y__standard_deviation  \
# 407                       5.897362                                4.301892
# 962                      31.950084                                1.169796
# 1171                      2.980798                                5.104971
# 726                       3.150255                                5.733789
# 354                       9.705953                                2.085736
# ...                            ...                                     ...
# 2068                      8.629084                                4.494803
# 1451                     16.639802                                2.168089
# 2385                      1.058292                                3.424742
# 1954                      3.088642                                4.336698
# 2581                      4.206869                                6.335921
#
#       RIGHT_ANKLE_DIST_y__autocorrelation__lag_10  \
# 407                                     -0.084347
# 962                                     -0.276656
# 1171                                     0.385300
# 726                                      0.005288
# 354                                     -0.099874
# ...                                           ...
# 2068                                     0.004738
# 1451                                     0.124402
# 2385                                     0.046478
# 1954                                     0.149983
# 2581                                    -0.237698
#
#       RIGHT_ANKLE_DIST_y__approximate_entropy__m_20__r_0.05  \
# 407                                            0.015267
# 962                                            0.021797
# 1171                                           0.037920
# 726                                            0.034406
# 354                                            0.017392
# ...                                                 ...
# 2068                                           0.035248
# 1451                                           0.017379
# 2385                                           0.036092
# 1954                                           0.040213
# 2581                                           0.018638
#
#       RIGHT_ANKLE_DIST_y__c3__lag_10  \
# 407                         5.789052
# 962                         0.149259
# 1171                      -11.660779
# 726                        20.073123
# 354                         0.580893
# ...                              ...
# 2068                        0.138104
# 1451                       -0.116839
# 2385                       -0.872135
# 1954                      -26.238590
# 2581                      -27.935323
#
#       RIGHT_ANKLE_DIST_y__cid_ce__normalize_True
# 407                                    12.462977
# 962                                    13.270384
# 1171                                    9.264517
# 726                                    12.183537
# 354                                    11.949898
# ...                                          ...
# 2068                                    7.785664
# 1451                                   12.027287
# 2385                                    9.548790
# 1954                                   10.349878
# 2581                                   11.548834
#
# [750 rows x 336 columns]

# %% [markdown]
# ## REGRESSION MODELS

# %%
#lINEAR REGRESSION - 
reg_model = LinearRegression().fit(X_train, y_train)
ypred_train = reg_model.predict(X_train)
ypred_test = reg_model.predict(X_test)
print("LINEAR REGRESSION")
print("Train Score: ")
print(r2_score(y_train, ypred_train))
print("Test Score: ")
print(r2_score(y_test, ypred_test))
# Out:
# LINEAR REGRESSION
# Train Score:
# 0.8661655344295471
# Test Score:
# -0.07101493378230013

# %%
reg_model.coef_
# Out:
# array([[-1.46338452e-02, -1.29417475e-03, -1.29609708e-01, ...,
#          2.16448729e+00, -4.56070113e-04, -2.67685379e-02],
#        [-9.20229842e-03,  3.32525997e-02, -5.68618845e-01, ...,
#          3.53447053e+00, -7.04947956e-04, -9.50081500e-03],
#        [-5.07722584e-01,  9.43242923e-01, -2.19082338e+00, ...,
#          3.95095626e+01,  6.92027900e-03, -3.99440545e-01],
#        ...,
#        [ 6.63444559e-03, -4.66291387e-02, -1.45263463e-01, ...,
#         -5.31712551e-01, -2.58647017e-04, -2.16458752e-03],
#        [ 9.25147331e-02,  1.06999739e-02,  3.04442592e-02, ...,
#          1.83294468e+00,  4.75133036e-04, -3.62979600e-02],
#        [-1.96324717e+01,  1.35621198e+01,  5.71410237e+01, ...,
#          3.78205668e+02,  1.38444913e-02, -1.34846182e+00]])

# %%
#K NEIGHBORS REGRESSOR - https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsRegressor.html#sklearn.neighbors.KNeighborsRegressor
knn_model = KNeighborsRegressor().fit(X_train, y_train)
ypred_train = knn_model.predict(X_train)
ypred_test = knn_model.predict(X_test)
print("KNN REGRESSION")
print("Train Score: ")
print(r2_score(y_train, ypred_train))
print("Test Score: ")
print(r2_score(y_test, ypred_test))
# Out:
# KNN REGRESSION
# Train Score:
# 0.5622893444637964
# Test Score:
# 0.30023494174173243

# %%
#LINEAR SVR - https://scikit-learn.org/stable/modules/generated/sklearn.svm.LinearSVR.html#sklearn.svm.LinearSVR
svr_model = MultiOutputRegressor(LinearSVR()).fit(X_train, y_train)
ypred_train = svr_model.predict(X_train)
ypred_test = svr_model.predict(X_test)
print("SVR REGRESSION")
print("Train Score: ")
print(r2_score(y_train, ypred_train))
print("Test Score: ")
print(r2_score(y_test, ypred_test))
# Out:
# C:\Users\mbase\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\mbase\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\mbase\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\mbase\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\mbase\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\mbase\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\mbase\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\mbase\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# SVR REGRESSION
# Train Score:
# -8.562758908300506
# Test Score:
# -8.857138796005602
# C:\Users\mbase\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(

# %%
#RIDGE REGRESSOR - https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.Ridge.html#sklearn.linear_model.Ridge
ridge_model = Ridge().fit(X_train, y_train)
ypred_train = ridge_model.predict(X_train)
ypred_test = ridge_model.predict(X_test)
print("RIDGE REGRESSION")
print("Train Score: ")
print(r2_score(y_train, ypred_train))
print("Test Score: ")
print(r2_score(y_test, ypred_test))
# Out:
# RIDGE REGRESSION
# Train Score:
# 0.8122275275754911
# Test Score:
# 0.17895841589181571
# C:\Users\mbase\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:156: LinAlgWarning: Ill-conditioned matrix (rcond=2.72546e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T

# %%
#ELASTIC NET - https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.ElasticNet.html#sklearn.linear_model.ElasticNet
elastic_model = ElasticNet().fit(X_train, y_train)
ypred_train = elastic_model.predict(X_train)
ypred_test = elastic_model.predict(X_test)
print("ELASTIC REGRESSION")
print("Train Score: ")
print(r2_score(y_train, ypred_train))
print("Test Score: ")
print(r2_score(y_test, ypred_test))
# Out:
# C:\Users\mbase\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.656e+00, tolerance: 1.572e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\mbase\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.186e+01, tolerance: 2.719e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\mbase\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.255e+03, tolerance: 5.954e-01
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\mbase\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.158e+00, tolerance: 1.801e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\mbase\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.353e+01, tolerance: 3.178e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\mbase\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.377e-01, tolerance: 5.320e-05
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\mbase\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.372e+00, tolerance: 5.836e-04
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\mbase\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.812e+01, tolerance: 4.228e-03
#   model = cd_fast.enet_coordinate_descent(
# ELASTIC REGRESSION
# Train Score:
# 0.2316625434064425
# Test Score:
# 0.1104570160079977
# C:\Users\mbase\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.131e+05, tolerance: 4.413e+01
#   model = cd_fast.enet_coordinate_descent(

# %%
#LASSO - https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.Lasso.html#sklearn.linear_model.Lasso
lasso_model = Lasso().fit(X_train, y_train)
ypred_train = lasso_model.predict(X_train)
ypred_test = lasso_model.predict(X_test)
print("LASSO REGRESSION")
print("Train Score: ")
print(r2_score(y_train, ypred_train))
print("Test Score: ")
print(r2_score(y_test, ypred_test))
# Out:
# C:\Users\mbase\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.750e+00, tolerance: 1.572e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\mbase\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.195e+01, tolerance: 2.719e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\mbase\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.401e+03, tolerance: 5.954e-01
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\mbase\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.295e+00, tolerance: 1.801e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\mbase\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.356e+01, tolerance: 3.178e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\mbase\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.388e-01, tolerance: 5.320e-05
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\mbase\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.403e+00, tolerance: 5.836e-04
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\mbase\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.832e+01, tolerance: 4.228e-03
#   model = cd_fast.enet_coordinate_descent(
# LASSO REGRESSION
# Train Score:
# 0.21053097142483507
# Test Score:
# 0.09956478756875314
# C:\Users\mbase\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.219e+05, tolerance: 4.413e+01
#   model = cd_fast.enet_coordinate_descent(

# %%
#Bayesian Ridge Regression? https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.BayesianRidge.html#sklearn.linear_model.BayesianRidge
bayesianRidge_model = MultiOutputRegressor(BayesianRidge()).fit(X_train, y_train)
ypred_train = bayesianRidge_model.predict(X_train)
ypred_test = bayesianRidge_model.predict(X_test)
print("BAYESIAN RIDGE REGRESSION")
print("Train Score: ")
print(r2_score(y_train, ypred_train))
print("Test Score: ")
print(r2_score(y_test, ypred_test))
# Out:
# BAYESIAN RIDGE REGRESSION
# Train Score:
# 0.2446107765170885
# Test Score:
# 0.10840062389598379

# %%
#Multitask Lasso? https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.MultiTaskLasso.html#sklearn.linear_model.MultiTaskLasso
mtLasso_model = MultiTaskLasso().fit(X_train, y_train)
ypred_train = mtLasso_model.predict(X_train)
ypred_test = mtLasso_model.predict(X_test)
print("MULTITASK LASSO REGRESSION")
print("Train Score: ")
print(r2_score(y_train, ypred_train))
print("Test Score: ")
print(r2_score(y_test, ypred_test))
# Out:
# MULTITASK LASSO REGRESSION
# Train Score:
# 0.43459249996183974
# Test Score:
# 0.2500423631918356
# C:\Users\mbase\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:2442: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 123763.88296779312, tolerance: 44.742666690619046
#   ) = cd_fast.enet_coordinate_descent_multi_task(

# %%
#Multitask Elastic Net? https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.MultiTaskElasticNet.html#sklearn.linear_model.MultiTaskElasticNet
mtNet_model = MultiTaskElasticNet().fit(X_train, y_train)
ypred_train = mtNet_model.predict(X_train)
ypred_test = mtNet_model.predict(X_test)
print("MULTITASK ELASTIC NET REGRESSION")
print("Train Score: ")
print(r2_score(y_train, ypred_train))
print("Test Score: ")
print(r2_score(y_test, ypred_test))
# Out:
# MULTITASK ELASTIC NET REGRESSION
# Train Score:
# 0.47409428082764027
# Test Score:
# 0.2832872668675543
# C:\Users\mbase\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:2442: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 114928.06616019216, tolerance: 44.742666690619046
#   ) = cd_fast.enet_coordinate_descent_multi_task(

# %%
#AdaBoost - https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.AdaBoostRegressor.html#sklearn.ensemble.AdaBoostRegressor
adaBoost_model = MultiOutputRegressor(AdaBoostRegressor()).fit(X_train, y_train)
ypred_train = adaBoost_model.predict(X_train)
ypred_test = adaBoost_model.predict(X_test)
print("ADABOOST REGRESSION")
print("Train Score: ")
print(r2_score(y_train, ypred_train))
print("Test Score: ")
print(r2_score(y_test, ypred_test))
# Out:
# ADABOOST REGRESSION
# Train Score:
# 0.6252841135188812
# Test Score:
# 0.5282724151837619

# %%
#Tree - https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeRegressor.html#sklearn.tree.DecisionTreeRegressor
tree_model = DecisionTreeRegressor().fit(X_train, y_train)
ypred_train = tree_model.predict(X_train)
ypred_test = tree_model.predict(X_test)
print("TREE REGRESSION")
print("Train Score: ")
print(r2_score(y_train, ypred_train))
print("Test Score: ")
print(r2_score(y_test, ypred_test))
# Out:
# TREE REGRESSION
# Train Score:
# 1.0
# Test Score:
# 0.6897205723340878

# %%
#Random Forest - https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestRegressor.html#sklearn.ensemble.RandomForestRegressor
rf_model = RandomForestRegressor().fit(X_train, y_train)
ypred_train = rf_model.predict(X_train)
ypred_test = rf_model.predict(X_test)
print("RANDOM FOREST REGRESSION")
print("Train Score: ")
print(r2_score(y_train, ypred_train))
print("Test Score: ")
print(r2_score(y_test, ypred_test))
# Out:
# RANDOM FOREST REGRESSION
# Train Score:
# 0.9656227990657266
# Test Score:
# 0.8144614341986967

# %% [markdown]
# # Parameter Tuning

# %%
n_estimators = 400
min_samples_split = 2
min_samples_leaf = 1
max_features = 'sqrt'
max_depth = None
bootstrap = False
# Out:
# C:\Users\mbase\anaconda3\lib\site-packages\sklearn\base.py:445: UserWarning: X does not have valid feature names, but RFECV was fitted with feature names
#   warnings.warn(

# %%
n_estimators = 400
min_samples_split = 2
min_samples_leaf = 1
max_features = 'sqrt'
max_depth = None
bootstrap = False

# %%
tuned_model = RandomForestRegressor(n_estimators = n_estimators, min_samples_split = min_samples_split, min_samples_leaf = min_samples_leaf, max_features = max_features, max_depth = max_depth, bootstrap = bootstrap).fit(X_train, y_train)

# %% [markdown]
# # Feature Selection

# %%
selected_RF = RFECV(tuned_model, step=25, cv=5)
selected_RF = selected_RF.fit(X_train, y_train)
ypred_train = selected_RF.predict(X_train)
ypred_test = selected_RF.predict(X_test)
print("RANDOM FOREST REGRESSION - SELECTED FEATURES")
print("Train Score: ")
print(r2_score(y_train, ypred_train))
print("Test Score: ")
print(r2_score(y_test, ypred_test))
# Out:
# C:\Users\mbase\anaconda3\lib\site-packages\sklearn\base.py:445: UserWarning: X does not have valid feature names, but RFECV was fitted with feature names
#   warnings.warn(
# RANDOM FOREST REGRESSION - SELECTED FEATURES
# Train Score:
# 1.0
# Test Score:
# 0.8943479316327403

# %%
names = pd.DataFrame(selected_RF.feature_names_in_)
best_features = [names.iloc[selected_RF.ranking_==1]]
best_features
# Out:
# [                                                 0
#  0                   LEFT_EYE_OUTER_POS_x__kurtosis
#  5     LEFT_EYE_OUTER_POS_x__cid_ce__normalize_True
#  6                   LEFT_EYE_OUTER_POS_y__kurtosis
#  8    LEFT_EYE_OUTER_POS_y__autocorrelation__lag_10
#  12                 LEFT_EYE_OUTER_DIST_x__kurtosis
#  ..                                             ...
#  311      LEFT_ANKLE_DIST_y__cid_ce__normalize_True
#  313          RIGHT_ANKLE_POS_x__standard_deviation
#  316                  RIGHT_ANKLE_POS_x__c3__lag_10
#  322                  RIGHT_ANKLE_POS_y__c3__lag_10
#  329     RIGHT_ANKLE_DIST_x__cid_ce__normalize_True
#
#  [111 rows x 1 columns]]

# %% [markdown]
# # Model Export

# %%
filename = 'model.sav'
pickle.dump(rf_model, open(filename, 'wb'))
