# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import r2_score

# %% [markdown]
# ### Loading data

# %%
data = pd.read_csv("parser_output/extracted_features_split_upsample_3_7.csv")
data = data.dropna()

# %%
data
# Out:
#       Unnamed: 0  Unnamed: 0.1  LEFT_EYE_OUTER_POS_x__abs_energy  \
# 0              0      1.000000                      3.857886e+06
# 1              1      1.000000                      3.855130e+06
# 2              2      1.000000                      2.988295e+06
# 3              3      1.000000                      5.229781e+06
# 4              4      1.000000                      3.804110e+06
# ...          ...           ...                               ...
# 2731        2731      1.004642                      7.675702e+06
# 2732        2732      1.002437                      6.251677e+06
# 2733        2733      1.004247                      6.060124e+06
# 2734        2734      1.005076                      7.223848e+06
# 2735        2735      1.001248                      8.786658e+06
#
#       LEFT_EYE_OUTER_POS_x__kurtosis  LEFT_EYE_OUTER_POS_x__mean  \
# 0                          -0.500597                  229.468110
# 1                          -0.483415                  231.389670
# 2                          -1.564327                  204.247290
# 3                           5.505027                  261.979358
# 4                          -1.651266                  221.742280
# ...                              ...                         ...
# 2731                       -0.428105                  308.844848
# 2732                       -0.295028                  278.277536
# 2733                       -0.447082                  262.692938
# 2734                       -1.371630                  289.099607
# 2735                        0.073066                  319.942215
#
#       LEFT_EYE_OUTER_POS_x__standard_deviation  LEFT_EYE_OUTER_POS_x__maximum  \
# 0                                    30.432529                     289.405029
# 1                                    27.503200                     295.279053
# 2                                    19.279543                     231.353989
# 3                                    13.406352                     288.362549
# 4                                    29.739429                     267.973663
# ...                                        ...                            ...
# 2731                                 23.695611                     354.531617
# 2732                                 26.620029                     340.216678
# 2733                                 38.227663                     341.837440
# 2734                                 37.607511                     361.694106
# 2735                                 31.805304                     392.931740
#
#       LEFT_EYE_OUTER_POS_x__autocorrelation__lag_1  \
# 0                                         0.989740
# 1                                         0.958905
# 2                                         0.984248
# 3                                         0.740990
# 4                                         0.980201
# ...                                            ...
# 2731                                      0.934245
# 2732                                      0.970170
# 2733                                      0.977176
# 2734                                      1.004394
# 2735                                      0.980145
#
#       LEFT_EYE_OUTER_POS_x__approximate_entropy__m_20__r_0.05  \
# 0                                              0.019048
# 1                                              0.019418
# 2                                              0.019418
# 3                                              0.017700
# 4                                              0.017700
# ...                                                 ...
# 2731                                           0.017084
# 2732                                           0.019958
# 2733                                           0.021461
# 2734                                           0.019952
# 2735                                           0.023761
#
#       LEFT_EYE_OUTER_POS_x__c3__lag_1  ...       key   loudness      mode  \
# 0                        1.261402e+07  ...  1.000000 -11.683000  1.000000
# 1                        1.296885e+07  ...  1.000000 -11.683000  1.000000
# 2                        8.737854e+06  ...  1.000000 -11.683000  1.000000
# 3                        1.824470e+07  ...  1.000000  -4.961000  1.000000
# 4                        1.132808e+07  ...  1.000000  -4.961000  1.000000
# ...                               ...  ...       ...        ...       ...
# 2731                     2.980213e+07  ...  1.008252  -8.051201  0.005007
# 2732                     2.204985e+07  ...  1.002027  -8.045381  0.004618
# 2733                     1.917193e+07  ...  2.006992  -2.717840  0.006860
# 2734                     2.539007e+07  ...  2.000985  -2.712416  0.004196
# 2735                     3.394232e+07  ...  2.008643  -2.709658  0.009932
#
#       speechiness  acousticness  instrumentalness  liveness   valence  \
# 0        0.471000      0.034600          0.069800  0.112000  0.394000
# 1        0.471000      0.034600          0.069800  0.112000  0.394000
# 2        0.471000      0.034600          0.069800  0.112000  0.394000
# 3        0.040600      0.013000          0.000000  0.094400  0.860000
# 4        0.040600      0.013000          0.000000  0.094400  0.860000
# ...           ...           ...               ...       ...       ...
# 2731     0.068594      0.435179          0.004971  0.121395  0.323141
# 2732     0.063657      0.442621          0.003104  0.117410  0.325989
# 2733     0.147851      0.099990          0.004684  0.294257  0.717822
# 2734     0.147485      0.103294          0.007745  0.294076  0.721028
# 2735     0.145579      0.101468          0.005916  0.295465  0.716712
#
#            tempo  time_signature
# 0     120.461000        4.000000
# 1     120.461000        4.000000
# 2     120.461000        4.000000
# 3     134.066000        4.000000
# 4     134.066000        4.000000
# ...          ...             ...
# 2731  110.026127        4.008011
# 2732  110.020294        4.003570
# 2733  120.028234        4.001796
# 2734  120.036452        4.007549
# 2735  120.036279        4.001005
#
# [2502 rows x 518 columns]

# %%
y = data[['danceability', 'energy', 'loudness', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo']]
x = data[data.columns[1:len(data.columns)-12]]

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.7)

# %%
print(X_train)
print(y_train)
# Out:
#       Unnamed: 0.1  LEFT_EYE_OUTER_POS_x__abs_energy  \
# 302       1.000000                      5.408350e+06
# 316       1.000000                      3.920748e+06
# 677       1.003120                      2.050428e+06
# 951       1.008045                      4.470571e+06
# 2685      1.009562                      8.413328e+06
# ...            ...                               ...
# 320       1.000000                      4.699587e+06
# 1104      1.003348                      2.654291e+06
# 2433      1.001924                      3.765726e+06
# 1893      1.001165                      3.111338e+06
# 945       1.004937                      3.521720e+06
#
#       LEFT_EYE_OUTER_POS_x__kurtosis  LEFT_EYE_OUTER_POS_x__mean  \
# 302                        -0.769056                  268.524526
# 316                         1.791160                  259.717662
# 677                        -1.154628                  196.403773
# 951                         0.312952                  207.642395
# 2685                       -0.799966                  312.277121
# ...                              ...                         ...
# 320                        -0.209098                  289.645387
# 1104                       -0.887614                  221.193012
# 2433                       -0.478698                  234.716637
# 1893                       -1.222476                  239.116426
# 945                        -0.050922                  185.801065
#
#       LEFT_EYE_OUTER_POS_x__standard_deviation  LEFT_EYE_OUTER_POS_x__maximum  \
# 302                                   2.431284                     272.879456
# 316                                  12.076279                     298.389069
# 677                                  10.652324                     210.923405
# 951                                  17.070392                     236.201251
# 2685                                 17.826102                     361.572006
# ...                                        ...                            ...
# 320                                   5.171466                     301.341766
# 1104                                 15.206721                     255.702401
# 2433                                 17.043689                     255.585893
# 1893                                 21.114147                     275.562033
# 945                                  18.702175                     233.104540
#
#       LEFT_EYE_OUTER_POS_x__autocorrelation__lag_1  \
# 302                                       0.907542
# 316                                       0.878003
# 677                                       0.973755
# 951                                       0.931770
# 2685                                      0.926522
# ...                                            ...
# 320                                       0.855461
# 1104                                      0.896958
# 2433                                      0.914515
# 1893                                      0.894969
# 945                                       0.970779
#
#       LEFT_EYE_OUTER_POS_x__approximate_entropy__m_20__r_0.05  \
# 302                                            0.018019
# 316                                            0.025975
# 677                                            0.030829
# 951                                            0.021719
# 2685                                           0.021261
# ...                                                 ...
# 320                                            0.027399
# 1104                                           0.036859
# 2433                                           0.025271
# 1893                                           0.035955
# 945                                            0.021851
#
#       LEFT_EYE_OUTER_POS_x__c3__lag_1  \
# 302                      1.936207e+07
# 316                      1.760277e+07
# 677                      7.618335e+06
# 951                      9.142275e+06
# 2685                     3.054399e+07
# ...                               ...
# 320                      2.430503e+07
# 1104                     1.091425e+07
# 2433                     1.316557e+07
# 1893                     1.384503e+07
# 945                      6.586802e+06
#
#       LEFT_EYE_OUTER_POS_x__cid_ce__normalize_True  ...  \
# 302                                       3.933005  ...
# 316                                       3.951244  ...
# 677                                       2.156274  ...
# 951                                       1.534073  ...
# 2685                                      3.680050  ...
# ...                                            ...  ...
# 320                                       4.131167  ...
# 1104                                      2.448902  ...
# 2433                                      2.099223  ...
# 1893                                      3.140909  ...
# 945                                       1.649720  ...
#
#       RIGHT_ANKLE_DIST_x__cid_ce__normalize_True  \
# 302                                     8.911296
# 316                                     8.174957
# 677                                     6.126378
# 951                                     9.205207
# 2685                                   10.585493
# ...                                          ...
# 320                                     7.665365
# 1104                                    6.466399
# 2433                                    7.272356
# 1893                                    9.311447
# 945                                    13.576987
#
#       RIGHT_ANKLE_DIST_y__abs_energy  RIGHT_ANKLE_DIST_y__kurtosis  \
# 302                       300.339694                      4.430522
# 316                      1893.585384                      5.193983
# 677                        11.878127                      2.826162
# 951                      4017.347798                      7.703552
# 2685                      360.440103                      5.219531
# ...                              ...                           ...
# 320                      3282.503127                     13.022397
# 1104                     1701.146253                      6.115835
# 2433                      319.796681                     21.068497
# 1893                     6153.314377                      3.552296
# 945                         9.712641                      7.824487
#
#       RIGHT_ANKLE_DIST_y__mean  RIGHT_ANKLE_DIST_y__standard_deviation  \
# 302                  -0.114537                                1.997851
# 316                  -0.072010                                5.713391
# 677                   0.089340                                0.473234
# 951                  -0.343440                                6.239694
# 2685                  0.050866                                2.052190
# ...                        ...                                     ...
# 320                  -0.001274                                7.656117
# 1104                 -0.195205                                5.609860
# 2433                  0.003136                                2.169626
# 1893                 -0.556361                               10.665527
# 945                   0.013034                                0.318506
#
#       RIGHT_ANKLE_DIST_y__maximum  RIGHT_ANKLE_DIST_y__autocorrelation__lag_1  \
# 302                      8.286804                                   -0.208279
# 316                     15.062592                                    0.019062
# 677                      1.417172                                    0.185832
# 951                     27.405472                                    0.508318
# 2685                     6.133998                                    0.022131
# ...                           ...                                         ...
# 320                     27.333221                                    0.473110
# 1104                    14.797581                                    0.370067
# 2433                     6.044752                                    0.140284
# 1893                    29.743440                                    0.024937
# 945                      1.329134                                    0.145021
#
#       RIGHT_ANKLE_DIST_y__approximate_entropy__m_20__r_0.05  \
# 302                                            0.018019
# 316                                            0.025975
# 677                                            0.031747
# 951                                            0.015500
# 2685                                           0.022506
# ...                                                 ...
# 320                                            0.027399
# 1104                                           0.029430
# 2433                                           0.027914
# 1893                                           0.035425
# 945                                            0.020059
#
#       RIGHT_ANKLE_DIST_y__c3__lag_1  \
# 302                       -0.746748
# 316                       -3.984514
# 677                       -0.014674
# 951                      -94.159531
# 2685                       0.046340
# ...                             ...
# 320                       86.195846
# 1104                      10.218933
# 2433                       2.721619
# 1893                     -72.111966
# 945                        0.006663
#
#       RIGHT_ANKLE_DIST_y__cid_ce__normalize_True
# 302                                    13.446886
# 316                                    10.664808
# 677                                     9.253134
# 951                                    10.186194
# 2685                                   12.969269
# ...                                          ...
# 320                                     7.743242
# 1104                                    8.324882
# 2433                                   10.832979
# 1893                                   10.310171
# 945                                    13.211155
#
# [750 rows x 505 columns]
#       danceability    energy   loudness  speechiness  acousticness  \
# 302       0.715000  0.951000  -6.488000     0.132000      0.152000
# 316       0.563000  0.664000  -5.044000     0.154000      0.335000
# 677       0.722991  0.266666 -12.772051     0.081545      0.297641
# 951       0.485521  0.485117  -8.980931     0.087931      0.241370
# 2685      0.908770  0.624099  -6.637762     0.108400      0.003383
# ...            ...       ...        ...          ...           ...
# 320       0.849000  0.424000  -9.579000     0.324000      0.063500
# 1104      0.709810  0.827993  -3.786838     0.069908      0.010451
# 2433      0.862440  0.565376  -4.957267     0.050170      0.016686
# 1893      0.335304  0.451979  -9.970475     0.046323      0.065188
# 945       0.522839  0.484477  -7.456108     0.026873      0.551975
#
#       instrumentalness  liveness   valence       tempo
# 302           0.000000  0.302000  0.671000  126.643000
# 316           0.000000  0.084900  0.688000  166.928000
# 677           0.092849  0.109214  0.282954   80.023521
# 951           0.009978  0.164897  0.353571  105.709988
# 2685          0.003178  0.105222  0.424491  150.020605
# ...                ...       ...       ...         ...
# 320           0.000000  0.083400  0.153000  145.887000
# 1104          0.002639  0.076609  0.916435  102.977370
# 2433          0.003597  0.096814  0.869258  134.067054
# 1893          0.037317  0.119123  0.233913  162.286925
# 945           0.006382  0.196538  0.293066   88.969613
#
# [750 rows x 9 columns]

# %% [markdown]
# ## Creating audio features-to-song dictionary
# #### Our goal is to phrase a (normally) continuous prediction problem in a classification way...
# #### This requires associating all samples with the proper class (a song)
# To do this, we take the music features of the samples and find the songs they correspond to.
# The songs are then used directly as labels in the classification model.
# This, unfortunately, gets rid of the utility of knowing the audio features up front.

# %%
# TODO: re-incorporate the audio features... either a multifactor classification model that basically creates bins 
# for each audio feature?

# %%
import logging
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
from spotipy.oauth2 import SpotifyOAuth

# Instantiate Spotify Client
logger = logging.getLogger()
logging.basicConfig()
CLIENT_ID="9793440f0a5047c59c70bcfcf91ad589"
CLIENT_SECRET= "b66dc3a5f9f34207bebee32a25745368"
REDIRECT_URL="http://localhost/"
client_credentials_manager = SpotifyClientCredentials(client_id = CLIENT_ID, client_secret = CLIENT_SECRET)
oAuth = SpotifyOAuth(client_id = CLIENT_ID, client_secret = CLIENT_SECRET, redirect_uri = REDIRECT_URL, scope = 'user-modify-playback-state')
sp = spotipy.Spotify(auth_manager =oAuth)

song_name_list = ['love_girl', 'party_rock_anthem', 'lite_spots', 'girlfriends_best_friend', 'scaredy_cat', 
                  'girl_anachronism', 'lil_darlin', 'el_invento', 'test_drive', 'weight_in_gold', 'easy', 'comethru', 
                  'classic', 'tongue_tied', 'motley', 'knife_talk', 'feed_the_fire', 'lose_it', 'thats_what_i_like', 
                  'humble', 'skeletons', 'stairway_to_heaven', 'slow_dancing_in_the_dark', 'peaches', 'kilby_girl', 
                  'jupiter_love', 'woman', 'get_up', 'throwin_elbows', 'power', 'ymca', 'all_i_wanna_do', 'easily',
                  'feed_the_fire', 'fool_around','good_4_u', 'knife_talk', 'levitating', 'sad_girlz_luv_money',
                  'tik_tok', 'a_thousand_miles']

artist_name_list = ['cnblue', 'lmfao', 'kaytranada', 'walkabout', 'dpr_ian', 'the_dresden_dolls', 'count_basie', 
                    'jose_gonzalez_calvaire', 'ariana_grande', 'gallant', 'wheein', 'jeremy_zucker', 'mkto', 
                    'grouplove', 'post_malone', 'drake', 'lucky_daye', 'swmrs', 'bruno_mars', 'kendrick_lamar', 
                    'keshi', 'led_zeppelin', 'joji', 'justin_bieber', 'backseat_lovers', 'trey_songz', 'doja_cat', 
                    'ciara', 'excision', 'little mix', 'village_people', 'jay_park', 'bruno_major', 'lucky_daye',
                    'yas', 'olivia_rodrigo', 'drake', 'dua_lipa', 'amaarae', 'kesha', 'vanessa_carlton']

def get_song(name_song, name_artist):
    results = sp.search(q=name_song + ' '+name_artist, type='track')
    items = results['tracks']['items']
    if len(items) > 0:
        return items[0]
    else:
        return None

# Spotify Song Features
def get_audio_features(song_name, artist_name):

    song = get_song(song_name, artist_name)

    #if get request didnt get anything
    if(song is None):
        return None

    song_features = sp.audio_features([song['uri']])

    audio_feature_list = ['danceability', 'energy', 'loudness', 'speechiness', 'acousticness', 
                          'instrumentalness', 'liveness', 'valence', 'tempo']

    audio_feat = pd.DataFrame(columns = audio_feature_list, index = range(1, 2))

    audio_feat['danceability'] = song_features[0].get('danceability')
    audio_feat['energy'] = song_features[0].get('energy')
    audio_feat['loudness'] = song_features[0].get('loudness')
    audio_feat['speechiness'] = song_features[0].get('speechiness')
    audio_feat['acousticness'] = song_features[0].get('acousticness')
    audio_feat['instrumentalness'] = song_features[0].get('instrumentalness')
    audio_feat['liveness'] = song_features[0].get('liveness')
    audio_feat['valence'] = song_features[0].get('valence')
    audio_feat['tempo'] = song_features[0].get('tempo')

    return audio_feat

# %%
extracted_features = pd.DataFrame()
featuresToSong = {}
featuresList = []

for index in range(len(song_name_list)):

    song_name = song_name_list[index]
    artist_name = artist_name_list[index]
    audio_feat = pd.DataFrame({'A' : []})

    try:
        audio_feat = get_audio_features(song_name, artist_name)
    except:
        oAuth = SpotifyOAuth(client_id = CLIENT_ID, client_secret = CLIENT_SECRET, redirect_uri = REDIRECT_URL, scope = 'user-modify-playback-state')
        sp = spotipy.Spotify(auth_manager =oAuth)
        audio_feat = get_audio_features(song_name, artist_name)

        
    if audio_feat is not None:
        if not audio_feat.empty:
    
            audio_feat = audio_feat.to_numpy()
            audio_feat = tuple(map(tuple, audio_feat))[0]
            identifier = (song_name, artist_name)

            featuresToSong[audio_feat] = (song_name, artist_name)
            featuresList.append((audio_feat, identifier))

# %%
arrs = [[], [], [], [], [], [], [], [], []]

for i in range(len(featuresList)):
    for j in range(len(featuresList[i][0])):
        arrs[j].append(featuresList[i][0][j])
# Out:
# [[0.637, 0.75, 0.884, 0.785, 0.801, 0.416, 0.268, 0.698, 0.38, 0.67, 0.795, 0.72, 0.56, 0.797, 0.849, 0.792, 0.853, 0.908, 0.719, 0.515, 0.677, 0.329, 0.478, 0.824, 0.964, 0.574, 0.566, 0.715, 0.613, 0.772, 0.635, 0.563, 0.849, 0.702, 0.87, 0.755, 0.56], [0.947, 0.727, 0.549, 0.505, 0.686, 0.883, 0.0368, 0.708, 0.438, 0.758, 0.178, 0.791, 0.936, 0.631, 0.424, 0.41, 0.56, 0.621, 0.265, 0.479, 0.696, 0.444, 0.483, 0.764, 0.595, 0.94, 0.855, 0.951, 0.668, 0.256, 0.476, 0.664, 0.424, 0.825, 0.523, 0.837, 0.825], [-2.659, -4.21, -11.683, -8.757, -4.252, -6.031, -23.97, -4.943, -5.526, -5.224, -11.991, -4.689, -5.835, -3.818, -9.579, -10.141, -4.961, -6.638, -12.782, -7.458, -6.181, -9.973, -8.985, -4.175, -6.887, -3.038, -4.016, -6.488, -6.867, -8.545, -10.101, -5.044, -9.579, -3.787, -8.052, -2.718, -3.862], [0.111, 0.142, 0.471, 0.0818, 0.0414, 0.15, 0.0338, 0.0454, 0.0962, 0.212, 0.0574, 0.124, 0.0439, 0.0786, 0.324, 0.0492, 0.0406, 0.102, 0.0754, 0.0261, 0.119, 0.0417, 0.0842, 0.0854, 0.109, 0.569, 0.211, 0.132, 0.267, 0.0481, 0.0639, 0.154, 0.324, 0.0601, 0.0602, 0.142, 0.0379], [0.103, 0.0189, 0.0346, 0.0209, 0.133, 0.314, 0.933, 0.0251, 0.0259, 0.36, 0.607, 0.0384, 0.00847, 0.0904, 0.0635, 0.334, 0.013, 0.000282, 0.296, 0.544, 0.321, 0.0578, 0.233, 0.0888, 0.0248, 0.00317, 0.0372, 0.152, 0.245, 0.491, 0.685, 0.335, 0.0635, 0.00883, 0.433, 0.0991, 0.323], [0.0, 0.0, 0.0698, 0.000662, 0.0, 0.0, 0.0522, 0.0, 1.29e-05, 0.0, 0.0, 0.0, 0.0, 3.71e-06, 0.0, 2.19e-05, 0.0, 5.39e-05, 0.0865, 0.00598, 0.0, 0.0352, 0.0, 0.00294, 5.14e-06, 0.0431, 0.000157, 0.0, 0.0, 0.00612, 9.14e-06, 0.0, 0.0, 0.0, 2.07e-05, 0.0, 0.0], [0.263, 0.266, 0.112, 0.109, 0.0882, 0.11, 0.888, 0.124, 0.154, 0.0996, 0.623, 0.157, 0.161, 0.0998, 0.0834, 0.106, 0.0944, 0.0958, 0.108, 0.191, 0.42, 0.113, 0.16, 0.117, 0.0405, 0.113, 0.181, 0.302, 0.0735, 0.144, 0.14, 0.0849, 0.0834, 0.0674, 0.113, 0.289, 0.161], [0.851, 0.359, 0.394, 0.304, 0.885, 0.788, 0.214, 0.322, 0.349, 0.585, 0.608, 0.756, 0.371, 0.288, 0.153, 0.561, 0.86, 0.421, 0.273, 0.284, 0.464, 0.225, 0.351, 0.881, 0.629, 0.362, 0.517, 0.671, 0.509, 0.357, 0.26, 0.688, 0.153, 0.915, 0.319, 0.714, 0.268], [143.951, 129.993, 120.461, 100.035, 120.007, 178.33, 63.577, 115.036, 179.404, 103.998, 93.982, 102.071, 112.96, 129.915, 145.887, 112.043, 134.066, 150.011, 80.021, 88.964, 90.03, 162.279, 105.7, 107.998, 128.593, 149.988, 172.966, 126.643, 96.176, 118.902, 119.738, 166.928, 145.887, 102.977, 110.02, 120.028, 94.931]]

# %%
x_train_arr = X_train.to_numpy()
y_train_arr = y_train.to_numpy()
x_test_arr = X_test.to_numpy()
y_test_arr = y_test.to_numpy()

# %%
def closest_value(input_lists, vals):
    arrs = [np.asarray(row) for row in input_lists]
    closests = [(np.abs(arrs[i] - vals[i])).argmin() for i in range(len(vals))]

    closestIndex = max(set(closests), key=closests.count)
    return closestIndex

trainLabels = []
for row in y_train_arr:
    rowVals = tuple(row)
    val = closest_value(arrs, rowVals)
    trainLabels.append(featuresList[val][1])
    
testLabels = []
for row in y_test_arr:
    rowVals = tuple(row)
    val = closest_value(arrs, rowVals)
    testLabels.append(featuresList[val][1])

# %%
song_artist_pairs = {
    '1':('thats_what_i_like','bruno_mars'),
    '2':('humble','kendrick_lamar'),
    '3':('skeletons','keshi'),
    '4':('slow_dancing_in_the_dark','joji'),
    '5':('lite_spots','kaytranada'),
    '6':('woman','doja_cat'),
    '7':('get_up','ciara'),
    '8':('throwin_elbows','excision'),
    '9':('power','little mix'),
    '10':('peaches','justin_bieber'),
    '11':('knife_talk','drake'),
    '12':('fool_around','yas'),
    '13':('levitating','dua_lipa'),
    '14':('feed_the_fire','lucky_daye'),
    '15':('easily','bruno_major'),
    '16':('good_4_u','olivia_rodrigo'),
    '17':('all_i_wanna_do','jay_park'),
    '18':('sad_girlz_luv_money','amaarae'),
    '19':('tik_tok','kesha'),
    '20':('ymca','village_people'),
    '21':('intuition_interlude','jamie_foxx'),
    '22':('kilby_girl','the_backseat_lovers'),
    '23':('a_thousand_miles','vanessa_carlton'),
    '24':('jupiter_love', 'trey_songz'),
    '25':('kilby_girl', 'backseat_lovers')
}

# %%
# Creating labels for the test and train datasets. Labels are songs

inv_map = {v: k for k, v in song_artist_pairs.items()}
trainLabelNums = [inv_map[label] for label in trainLabels]
testLabelNums = [inv_map[label] for label in testLabels]

print(trainLabelNums)
# Out:
# ['19', '17', '7', '13', '1', '7', '7', '8', '15', '17', '20', '17', '10', '24', '2', '5', '2', '6', '2', '11', '13', '13', '18', '11', '11', '20', '3', '20', '20', '20', '10', '6', '3', '4', '6', '13', '13', '6', '2', '12', '20', '10', '16', '3', '4', '4', '16', '12', '12', '13', '17', '18', '18', '4', '6', '11', '19', '10', '23', '7', '25', '11', '1', '11', '15', '6', '5', '11', '16', '4', '5', '11', '2', '8', '19', '6', '7', '6', '11', '1', '2', '4', '15', '8', '24', '7', '15', '6', '7', '12', '7', '4', '11', '13', '3', '3', '7', '15', '4', '11', '5', '11', '12', '17', '3', '25', '12', '17', '18', '11', '15', '3', '2', '2', '11', '4', '13', '13', '15', '6', '8', '3', '5', '4', '15', '11', '3', '12', '5', '17', '5', '19', '20', '10', '11', '7', '18', '19', '3', '2', '10', '5', '25', '7', '7', '7', '15', '20', '18', '2', '10', '7', '20', '20', '18', '11', '4', '3', '1', '5', '5', '7', '17', '2', '3', '11', '4', '18', '7', '15', '19', '15', '6', '8', '6', '1', '11', '6', '17', '1', '5', '6', '17', '3', '12', '1', '5', '6', '18', '2', '11', '7', '5', '17', '15', '3', '11', '5', '11', '2', '6', '5', '6', '8', '1', '5', '17', '6', '12', '18', '11', '12', '8', '13', '3', '8', '1', '12', '12', '17', '15', '1', '20', '18', '11', '16', '5', '1', '1', '10', '24', '13', '17', '8', '5', '1', '3', '2', '1', '2', '17', '1', '17', '18', '11', '2', '10', '3', '18', '4', '6', '13', '11', '19', '15', '5', '11', '6', '19', '13', '19', '24', '15', '2', '11', '19', '8', '8', '19', '11', '11', '18', '11', '18', '6', '3', '11', '4', '20', '1', '6', '10', '20', '4', '8', '2', '12', '7', '24', '1', '2', '4', '12', '8', '13', '5', '3', '6', '6', '6', '7', '18', '15', '6', '17', '13', '4', '8', '16', '2', '16', '5', '5', '20', '16', '6', '2', '6', '10', '10', '5', '4', '13', '16', '16', '6', '4', '4', '6', '7', '24', '17', '5', '17', '11', '13', '12', '8', '6', '20', '17', '19', '5', '11', '11', '10', '3', '5', '1', '3', '3', '2', '8', '2', '8', '8', '25', '5', '16', '7', '4', '5', '5', '4', '15', '1', '5', '16', '7', '2', '5', '15', '4', '8', '18', '16', '1', '4', '10', '17', '15', '1', '7', '11', '17', '4', '13', '13', '12', '7', '19', '1', '24', '8', '4', '2', '17', '12', '17', '18', '24', '13', '24', '2', '2', '13', '20', '5', '16', '11', '2', '13', '25', '5', '20', '4', '5', '15', '2', '16', '1', '5', '12', '2', '20', '3', '2', '4', '17', '1', '12', '1', '18', '5', '2', '6', '8', '12', '8', '16', '5', '10', '7', '16', '24', '8', '8', '7', '4', '11', '4', '6', '2', '15', '1', '15', '19', '4', '19', '15', '10', '5', '6', '11', '19', '3', '8', '19', '7', '12', '12', '1', '5', '4', '4', '16', '8', '17', '6', '6', '15', '8', '12', '3', '1', '6', '8', '19', '11', '13', '4', '20', '7', '3', '17', '16', '16', '25', '2', '11', '11', '20', '11', '1', '10', '19', '8', '1', '12', '2', '1', '7', '7', '11', '7', '4', '19', '1', '4', '25', '11', '11', '6', '5', '5', '6', '11', '7', '20', '7', '2', '10', '5', '16', '6', '8', '11', '3', '11', '19', '17', '11', '2', '18', '4', '8', '12', '2', '8', '4', '16', '15', '18', '4', '6', '18', '10', '11', '3', '3', '13', '5', '5', '15', '2', '7', '10', '19', '15', '11', '12', '11', '3', '3', '16', '8', '20', '6', '17', '17', '17', '11', '8', '12', '4', '11', '12', '12', '4', '6', '8', '10', '1', '4', '19', '18', '11', '3', '18', '24', '5', '4', '1', '2', '18', '20', '10', '16', '20', '13', '3', '17', '13', '11', '1', '1', '8', '1', '11', '7', '4', '12', '15', '20', '16', '7', '1', '2', '15', '2', '4', '18', '19', '4', '17', '11', '4', '15', '6', '2', '3', '1', '18', '3', '11', '11', '2', '17', '1', '4', '1', '8', '8', '11', '16', '5', '12', '15', '19', '18', '20', '4', '1', '12', '11', '20', '11', '17', '4', '16', '11', '1', '7', '7', '11', '20', '17', '23', '4', '7', '24', '11', '1', '19', '13', '25', '16', '15', '5', '5', '20', '6', '6', '4', '13', '16', '12', '17', '6', '7', '2', '2', '10', '18', '2', '20', '12', '19', '4', '5', '4', '5', '4', '19', '6', '3', '3', '6', '25', '4', '2', '11', '8', '11', '23', '15', '15',  ...

# %%
clf = SVC()
clf.fit(X_train, trainLabelNums)
# Out:
# SVC()

# %%
ypred_train = clf.predict(X_train)
ypred_test = clf.predict(X_test)

# %%
print("LINEAR REGRESSION")
print("Train Score: ")
print(r2_score(trainLabelNums, ypred_train))
print("Test Score: ")
print(r2_score(testLabelNums, ypred_test))
# Out:
# LINEAR REGRESSION
# Train Score:
# -0.028039897543240544
# Test Score:
# -0.054772671716210475
# /opt/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:63: FutureWarning: Arrays of bytes/strings is being converted to decimal numbers if dtype='numeric'. This behavior is deprecated in 0.24 and will be removed in 1.1 (renaming of 0.26). Please convert your data to numeric values explicitly instead.
#   return f(*args, **kwargs)
# /opt/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:63: FutureWarning: Arrays of bytes/strings is being converted to decimal numbers if dtype='numeric'. This behavior is deprecated in 0.24 and will be removed in 1.1 (renaming of 0.26). Please convert your data to numeric values explicitly instead.
#   return f(*args, **kwargs)
# /opt/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:63: FutureWarning: Arrays of bytes/strings is being converted to decimal numbers if dtype='numeric'. This behavior is deprecated in 0.24 and will be removed in 1.1 (renaming of 0.26). Please convert your data to numeric values explicitly instead.
#   return f(*args, **kwargs)
# /opt/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:63: FutureWarning: Arrays of bytes/strings is being converted to decimal numbers if dtype='numeric'. This behavior is deprecated in 0.24 and will be removed in 1.1 (renaming of 0.26). Please convert your data to numeric values explicitly instead.
#   return f(*args, **kwargs)
