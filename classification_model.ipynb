# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import r2_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

# %% [markdown]
# ### Loading data

# %%
data = pd.read_csv("parser_output/extracted_features_split_3_28_upsample.csv")
data = data.dropna()

# %%
data
# Out:
#       Unnamed: 0  Unnamed: 0.1  LEFT_EYE_OUTER_POS_x__kurtosis  \
# 0              0      1.000000                       -0.500597
# 1              1      1.000000                       -0.483415
# 2              2      1.000000                       -1.564327
# 3              3      1.000000                        5.505027
# 4              4      1.000000                       -1.651266
# ...          ...           ...                             ...
# 2731        2731      1.009253                       -0.429160
# 2732        2732      1.007549                       -0.295804
# 2733        2733      1.007922                       -0.453641
# 2734        2734      1.002436                       -1.371323
# 2735        2735      1.002979                        0.073124
#
#       LEFT_EYE_OUTER_POS_x__standard_deviation  \
# 0                                    30.432529
# 1                                    27.503200
# 2                                    19.279543
# 3                                    13.406352
# 4                                    29.739429
# ...                                        ...
# 2731                                 23.699830
# 2732                                 26.620043
# 2733                                 38.225051
# 2734                                 37.603216
# 2735                                 31.811209
#
#       LEFT_EYE_OUTER_POS_x__autocorrelation__lag_10  \
# 0                                          0.473995
# 1                                          0.059756
# 2                                          0.591867
# 3                                          0.227827
# 4                                          0.529723
# ...                                             ...
# 2731                                       0.071023
# 2732                                       0.135026
# 2733                                       0.551654
# 2734                                       0.803757
# 2735                                       0.157222
#
#       LEFT_EYE_OUTER_POS_x__approximate_entropy__m_20__r_0.05  \
# 0                                              0.019048
# 1                                              0.019418
# 2                                              0.019418
# 3                                              0.017700
# 4                                              0.017700
# ...                                                 ...
# 2731                                           0.024342
# 2732                                           0.023765
# 2733                                           0.021456
# 2734                                           0.024938
# 2735                                           0.017156
#
#       LEFT_EYE_OUTER_POS_x__c3__lag_10  \
# 0                         1.156625e+07
# 1                         1.235949e+07
# 2                         8.488430e+06
# 3                         1.841696e+07
# 4                         9.677430e+06
# ...                                ...
# 2731                      2.881071e+07
# 2732                      2.151611e+07
# 2733                      1.693204e+07
# 2734                      2.479525e+07
# 2735                      3.446335e+07
#
#       LEFT_EYE_OUTER_POS_x__cid_ce__normalize_True  \
# 0                                         1.356488
# 1                                         2.453771
# 2                                         1.356007
# 3                                         4.185149
# 4                                         1.264870
# ...                                            ...
# 2731                                      3.200530
# 2732                                      2.511810
# 2733                                      1.299832
# 2734                                      1.333436
# 2735                                      2.112359
#
#       LEFT_EYE_OUTER_POS_y__kurtosis  \
# 0                           0.947163
# 1                           5.098091
# 2                          -1.310822
# 3                          -0.679397
# 4                          -0.672379
# ...                              ...
# 2731                        4.065613
# 2732                       -0.992072
# 2733                        2.911378
# 2734                       -0.302217
# 2735                       -0.279968
#
#       LEFT_EYE_OUTER_POS_y__standard_deviation  ...       key   loudness  \
# 0                                    32.875727  ...  1.000000 -11.683000
# 1                                    42.493897  ...  1.000000 -11.683000
# 2                                    37.907508  ...  1.000000 -11.683000
# 3                                    14.547386  ...  1.000000  -4.961000
# 4                                    22.561584  ...  1.000000  -4.961000
# ...                                        ...  ...       ...        ...
# 2731                                 26.700536  ...  1.001468  -8.044790
# 2732                                 14.717245  ...  1.009341  -8.044112
# 2733                                 22.203969  ...  2.005843  -2.717820
# 2734                                 19.361277  ...  2.006492  -2.708844
# 2735                                 14.610880  ...  2.004956  -2.716299
#
#           mode  speechiness  acousticness  instrumentalness  liveness  \
# 0     1.000000     0.471000      0.034600          0.069800  0.112000
# 1     1.000000     0.471000      0.034600          0.069800  0.112000
# 2     1.000000     0.471000      0.034600          0.069800  0.112000
# 3     1.000000     0.040600      0.013000          0.000000  0.094400
# 4     1.000000     0.040600      0.013000          0.000000  0.094400
# ...        ...          ...           ...               ...       ...
# 2731  0.009961     0.064800      0.437464          0.001176  0.119714
# 2732  0.009960     0.063448      0.440401          0.000517  0.114702
# 2733  0.007675     0.149796      0.102007          0.001369  0.295883
# 2734  0.002764     0.146745      0.107539          0.002919  0.293654
# 2735  0.002322     0.151568      0.102394          0.005549  0.291190
#
#        valence       tempo  time_signature
# 0     0.394000  120.461000        4.000000
# 1     0.394000  120.461000        4.000000
# 2     0.394000  120.461000        4.000000
# 3     0.860000  134.066000        4.000000
# 4     0.860000  134.066000        4.000000
# ...        ...         ...             ...
# 2731  0.321766  110.022306        4.006691
# 2732  0.324953  110.021905        4.003841
# 2733  0.714539  120.035184        4.004975
# 2734  0.715673  120.029463        4.006945
# 2735  0.721275  120.035093        4.003433
#
# [2502 rows x 350 columns]

# %%
y = data[['danceability', 'energy', 'loudness', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo']]
x = data[data.columns[2:len(data.columns)-12]]

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.4)

# %%
print(X_train)
print(y_train)
# Out:
#       LEFT_EYE_OUTER_POS_x__kurtosis  \
# 1823                        0.075342
# 662                        -1.321660
# 1574                       -1.324535
# 232                        -0.307720
# 2637                       -0.705276
# ...                              ...
# 114                        -1.475135
# 2480                       -0.245856
# 1262                       -1.433088
# 989                         0.670709
# 2077                       -0.626971
#
#       LEFT_EYE_OUTER_POS_x__standard_deviation  \
# 1823                                 31.806111
# 662                                  18.046121
# 1574                                 18.049231
# 232                                   6.181533
# 2637                                 18.574666
# ...                                        ...
# 114                                  13.885716
# 2480                                  9.691992
# 1262                                 16.620361
# 989                                   5.496788
# 2077                                 12.541228
#
#       LEFT_EYE_OUTER_POS_x__autocorrelation__lag_10  \
# 1823                                       0.155062
# 662                                       -0.424863
# 1574                                      -0.421252
# 232                                        0.471386
# 2637                                      -0.647518
# ...                                             ...
# 114                                       -0.696412
# 2480                                       0.353006
# 1262                                       0.005329
# 989                                        0.089102
# 2077                                       0.204126
#
#       LEFT_EYE_OUTER_POS_x__approximate_entropy__m_20__r_0.05  \
# 1823                                           0.024359
# 662                                            0.021638
# 1574                                           0.027127
# 232                                            0.039221
# 2637                                           0.025907
# ...                                                 ...
# 114                                            0.032790
# 2480                                           0.029017
# 1262                                           0.029761
# 989                                            0.035934
# 2077                                           0.029675
#
#       LEFT_EYE_OUTER_POS_x__c3__lag_10  \
# 1823                      3.446335e+07
# 662                       4.466538e+06
# 1574                      4.466538e+06
# 232                       8.055790e+06
# 2637                      1.364560e+07
# ...                                ...
# 114                       1.771295e+07
# 2480                      7.964410e+06
# 1262                      1.686386e+07
# 989                       1.641430e+07
# 2077                      6.192096e+06
#
#       LEFT_EYE_OUTER_POS_x__cid_ce__normalize_True  \
# 1823                                      2.119616
# 662                                       2.278866
# 1574                                      2.277875
# 232                                       4.099941
# 2637                                      2.761618
# ...                                            ...
# 114                                       3.228334
# 2480                                      2.014426
# 1262                                      1.860158
# 989                                       2.573937
# 2077                                      2.307047
#
#       LEFT_EYE_OUTER_POS_y__kurtosis  \
# 1823                       -0.277867
# 662                        -1.104296
# 1574                       -1.100514
# 232                         0.947332
# 2637                        1.429086
# ...                              ...
# 114                         2.002761
# 2480                       -0.302737
# 1262                       -1.459181
# 989                         2.454358
# 2077                       -0.328019
#
#       LEFT_EYE_OUTER_POS_y__standard_deviation  \
# 1823                                 14.615436
# 662                                   7.316799
# 1574                                  7.309679
# 232                                  16.444209
# 2637                                 17.671582
# ...                                        ...
# 114                                  15.069064
# 2480                                  7.674588
# 1262                                  5.846904
# 989                                  18.888536
# 2077                                  4.576906
#
#       LEFT_EYE_OUTER_POS_y__autocorrelation__lag_10  \
# 1823                                       0.005460
# 662                                        0.521645
# 1574                                       0.524761
# 232                                       -0.237455
# 2637                                       0.173887
# ...                                             ...
# 114                                       -0.095218
# 2480                                       0.121461
# 1262                                       0.261584
# 989                                       -0.338802
# 2077                                      -0.221536
#
#       LEFT_EYE_OUTER_POS_y__approximate_entropy__m_20__r_0.05  ...  \
# 1823                                           0.023372        ...
# 662                                            0.025159        ...
# 1574                                           0.025107        ...
# 232                                            0.039221        ...
# 2637                                           0.027183        ...
# ...                                                 ...        ...
# 114                                            0.032790        ...
# 2480                                           0.023754        ...
# 1262                                           0.031654        ...
# 989                                            0.031431        ...
# 2077                                           0.029881        ...
#
#       RIGHT_ANKLE_DIST_x__autocorrelation__lag_10  \
# 1823                                    -0.118599
# 662                                     -0.007122
# 1574                                    -0.008402
# 232                                     -0.030983
# 2637                                    -0.385149
# ...                                           ...
# 114                                     -0.184419
# 2480                                    -0.031511
# 1262                                    -0.070235
# 989                                      0.043604
# 2077                                    -0.074334
#
#       RIGHT_ANKLE_DIST_x__approximate_entropy__m_20__r_0.05  \
# 1823                                           0.024971
# 662                                            0.022681
# 1574                                           0.022099
# 232                                            0.039221
# 2637                                           0.029641
# ...                                                 ...
# 114                                            0.032790
# 2480                                           0.031933
# 1262                                           0.032931
# 989                                            0.033303
# 2077                                           0.030046
#
#       RIGHT_ANKLE_DIST_x__c3__lag_10  \
# 1823                       98.056130
# 662                         0.192435
# 1574                        0.189010
# 232                         0.000641
# 2637                     -624.103386
# ...                              ...
# 114                       -15.199819
# 2480                       -0.843759
# 1262                       -0.161251
# 989                        73.076095
# 2077                       -0.265096
#
#       RIGHT_ANKLE_DIST_x__cid_ce__normalize_True  \
# 1823                                    9.183600
# 662                                     8.946757
# 1574                                    8.946233
# 232                                     5.422182
# 2637                                    7.419570
# ...                                          ...
# 114                                     8.152205
# 2480                                   10.625619
# 1262                                    9.724785
# 989                                     8.049236
# 2077                                   11.813639
#
#       RIGHT_ANKLE_DIST_y__kurtosis  RIGHT_ANKLE_DIST_y__standard_deviation  \
# 1823                     25.837498                                7.208357
# 662                       6.490999                                1.306726
# 1574                      6.496116                                1.314577
# 232                      15.110816                                1.187944
# 2637                      4.929848                                5.844087
# ...                            ...                                     ...
# 114                       6.614752                                2.612798
# 2480                     14.063439                                3.647302
# 1262                     15.769826                                7.768833
# 989                       1.640536                                2.254413
# 2077                      8.413329                                2.256133
#
#       RIGHT_ANKLE_DIST_y__autocorrelation__lag_10  \
# 1823                                     0.019753
# 662                                     -0.174405
# 1574                                    -0.177416
# 232                                     -0.164337
# 2637                                     0.043451
# ...                                           ...
# 114                                      0.044839
# 2480                                    -0.043109
# 1262                                    -0.059297
# 989                                     -0.062264
# 2077                                    -0.057446
#
#       RIGHT_ANKLE_DIST_y__approximate_entropy__m_20__r_0.05  \
# 1823                                           0.019956
# 662                                            0.022628
# 1574                                           0.021190
# 232                                            0.039221
# 2637                                           0.032606
# ...                                                 ...
# 114                                            0.032790
# 2480                                           0.029634
# 1262                                           0.026456
# 989                                            0.036358
# 2077                                           0.027055
#
#       RIGHT_ANKLE_DIST_y__c3__lag_10  \
# 1823                        2.074590
# 662                        -0.204513
# 1574                       -0.205370
# 232                         0.185021
# 2637                       -0.525321
# ...                              ...
# 114                         0.231916
# 2480                       -0.519939
# 1262                       -1.652140
# 989                        -0.759391
# 2077                       -2.398737
#
#       RIGHT_ANKLE_DIST_y__cid_ce__normalize_True
# 1823                                   11.036705
# 662                                    10.438762
# 1574                                   10.438048
# 232                                     7.229405
# 2637                                   11.163314
# ...                                          ...
# 114                                     9.651036
# 2480                                    9.484175
# 1262                                   10.382255
# 989                                     9.849095
# 2077                                   10.710978
#
# [1501 rows x 336 columns]
#       danceability    energy   loudness  speechiness  acousticness  \
# 1823      0.764731  0.837441  -2.717625     0.148619      0.106838
# 662       0.886499  0.553063 -11.677826     0.471636      0.036064
# 1574      0.888863  0.550023 -11.676665     0.472823      0.042977
# 232       0.964000  0.595000  -6.887000     0.109000      0.024800
# 2637      0.968555  0.599343  -6.885700     0.118607      0.034295
# ...            ...       ...        ...          ...           ...
# 114       0.574000  0.940000  -3.038000     0.569000      0.003170
# 2480      0.759947  0.845507  -2.713996     0.144963      0.108412
# 1262      0.522812  0.488141  -7.451663     0.030121      0.548831
# 989       0.833778  0.770592  -4.166453     0.091318      0.098417
# 2077      0.565160  0.664346  -5.043755     0.160461      0.343270
#
#       instrumentalness  liveness   valence       tempo
# 1823          0.001404  0.294325  0.721991  120.032888
# 662           0.070343  0.118651  0.399792  120.468268
# 1574          0.073027  0.121301  0.396881  120.465493
# 232           0.000005  0.040500  0.629000  128.593000
# 2637          0.003933  0.048009  0.631512  128.598285
# ...                ...       ...       ...         ...
# 114           0.043100  0.113000  0.362000  149.988000
# 2480          0.002179  0.294844  0.720923  120.031368
# 1262          0.008624  0.194133  0.291305   88.970781
# 989           0.006428  0.122008  0.884473  108.001925
# 2077          0.005543  0.091976  0.690301  166.935534
#
# [1501 rows x 9 columns]

# %% [markdown]
# ## Creating audio features-to-song dictionary
# #### Our goal is to phrase a (normally) continuous prediction problem in a classification way...
# #### This requires associating all samples with the proper class (a song)
# To do this, we take the music features of the samples and find the songs they correspond to.
# The songs are then used directly as labels in the classification model.
# This, unfortunately, gets rid of the utility of knowing the audio features up front.

# %%
# TODO: re-incorporate the audio features... either a multifactor classification model that basically creates bins 
# for each audio feature?

# %%
import logging
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
from spotipy.oauth2 import SpotifyOAuth

# Instantiate Spotify Client
logger = logging.getLogger()
logging.basicConfig()
CLIENT_ID="9793440f0a5047c59c70bcfcf91ad589"
CLIENT_SECRET= "b66dc3a5f9f34207bebee32a25745368"
REDIRECT_URL="http://localhost/"
client_credentials_manager = SpotifyClientCredentials(client_id = CLIENT_ID, client_secret = CLIENT_SECRET)
oAuth = SpotifyOAuth(client_id = CLIENT_ID, client_secret = CLIENT_SECRET, redirect_uri = REDIRECT_URL, scope = 'user-modify-playback-state')
sp = spotipy.Spotify(auth_manager =oAuth)

song_name_list = ['love_girl', 'party_rock_anthem', 'lite_spots', 'girlfriends_best_friend', 'scaredy_cat', 
                  'girl_anachronism', 'lil_darlin', 'el_invento', 'test_drive', 'weight_in_gold', 'easy', 'comethru', 
                  'classic', 'tongue_tied', 'motley', 'knife_talk', 'feed_the_fire', 'lose_it', 'thats_what_i_like', 
                  'humble', 'skeletons', 'stairway_to_heaven', 'slow_dancing_in_the_dark', 'peaches', 'kilby_girl', 
                  'jupiter_love', 'woman', 'get_up', 'throwin_elbows', 'power', 'ymca', 'all_i_wanna_do', 'easily',
                  'feed_the_fire', 'fool_around','good_4_u', 'knife_talk', 'levitating', 'sad_girlz_luv_money',
                  'tik_tok', 'a_thousand_miles']

artist_name_list = ['cnblue', 'lmfao', 'kaytranada', 'walkabout', 'dpr_ian', 'the_dresden_dolls', 'count_basie', 
                    'jose_gonzalez_calvaire', 'ariana_grande', 'gallant', 'wheein', 'jeremy_zucker', 'mkto', 
                    'grouplove', 'post_malone', 'drake', 'lucky_daye', 'swmrs', 'bruno_mars', 'kendrick_lamar', 
                    'keshi', 'led_zeppelin', 'joji', 'justin_bieber', 'backseat_lovers', 'trey_songz', 'doja_cat', 
                    'ciara', 'excision', 'little mix', 'village_people', 'jay_park', 'bruno_major', 'lucky_daye',
                    'yas', 'olivia_rodrigo', 'drake', 'dua_lipa', 'amaarae', 'kesha', 'vanessa_carlton']

def get_song(name_song, name_artist):
    results = sp.search(q=name_song + ' '+name_artist, type='track')
    items = results['tracks']['items']
    if len(items) > 0:
        return items[0]
    else:
        return None

# Spotify Song Features
def get_audio_features(song_name, artist_name):

    song = get_song(song_name, artist_name)

    #if get request didnt get anything
    if(song is None):
        return None

    song_features = sp.audio_features([song['uri']])

    audio_feature_list = ['danceability', 'energy', 'loudness', 'speechiness', 'acousticness', 
                          'instrumentalness', 'liveness', 'valence', 'tempo']

    audio_feat = pd.DataFrame(columns = audio_feature_list, index = range(1, 2))

    audio_feat['danceability'] = song_features[0].get('danceability')
    audio_feat['energy'] = song_features[0].get('energy')
    audio_feat['loudness'] = song_features[0].get('loudness')
    audio_feat['speechiness'] = song_features[0].get('speechiness')
    audio_feat['acousticness'] = song_features[0].get('acousticness')
    audio_feat['instrumentalness'] = song_features[0].get('instrumentalness')
    audio_feat['liveness'] = song_features[0].get('liveness')
    audio_feat['valence'] = song_features[0].get('valence')
    audio_feat['tempo'] = song_features[0].get('tempo')

    return audio_feat

# %%
extracted_features = pd.DataFrame()
featuresToSong = {}
featuresList = []

for index in range(len(song_name_list)):

    song_name = song_name_list[index]
    artist_name = artist_name_list[index]
    audio_feat = pd.DataFrame({'A' : []})

    try:
        audio_feat = get_audio_features(song_name, artist_name)
    except:
        oAuth = SpotifyOAuth(client_id = CLIENT_ID, client_secret = CLIENT_SECRET, redirect_uri = REDIRECT_URL, scope = 'user-modify-playback-state')
        sp = spotipy.Spotify(auth_manager =oAuth)
        audio_feat = get_audio_features(song_name, artist_name)

        
    if audio_feat is not None:
        if not audio_feat.empty:
    
            audio_feat = audio_feat.to_numpy()
            audio_feat = tuple(map(tuple, audio_feat))[0]
            identifier = (song_name, artist_name)

            featuresToSong[audio_feat] = (song_name, artist_name)
            featuresList.append((audio_feat, identifier))

# %%
arrs = [[], [], [], [], [], [], [], [], []]

for i in range(len(featuresList)):
    for j in range(len(featuresList[i][0])):
        arrs[j].append(featuresList[i][0][j])

# %%
x_train_arr = X_train.to_numpy()
y_train_arr = y_train.to_numpy()
x_test_arr = X_test.to_numpy()
y_test_arr = y_test.to_numpy()

# %%
def closest_value(input_lists, vals):
    arrs = [np.asarray(row) for row in input_lists]
    closests = [(np.abs(arrs[i] - vals[i])).argmin() for i in range(len(vals))]

    closestIndex = max(set(closests), key=closests.count)
    return closestIndex

trainLabels = []
for row in y_train_arr:
    rowVals = tuple(row)
    val = closest_value(arrs, rowVals)
    trainLabels.append(featuresList[val][1])
    
testLabels = []
for row in y_test_arr:
    rowVals = tuple(row)
    val = closest_value(arrs, rowVals)
    testLabels.append(featuresList[val][1])

# %%
song_artist_pairs = {
    '1':('thats_what_i_like','bruno_mars'),
    '2':('humble','kendrick_lamar'),
    '3':('skeletons','keshi'),
    '4':('slow_dancing_in_the_dark','joji'),
    '5':('lite_spots','kaytranada'),
    '6':('woman','doja_cat'),
    '7':('get_up','ciara'),
    '8':('throwin_elbows','excision'),
    '9':('power','little mix'),
    '10':('peaches','justin_bieber'),
    '11':('knife_talk','drake'),
    '12':('fool_around','yas'),
    '13':('levitating','dua_lipa'),
    '14':('feed_the_fire','lucky_daye'),
    '15':('easily','bruno_major'),
    '16':('good_4_u','olivia_rodrigo'),
    '17':('all_i_wanna_do','jay_park'),
    '18':('sad_girlz_luv_money','amaarae'),
    '19':('tik_tok','kesha'),
    '20':('ymca','village_people'),
    '21':('intuition_interlude','jamie_foxx'),
    '22':('kilby_girl','the_backseat_lovers'),
    '23':('a_thousand_miles','vanessa_carlton'),
    '24':('jupiter_love', 'trey_songz'),
    '25':('kilby_girl', 'backseat_lovers')
}

# %%
# Creating labels for the test and train datasets. Labels are songs

inv_map = {v: k for k, v in song_artist_pairs.items()}
trainLabelNums = [inv_map[label] for label in trainLabels]
testLabelNums = [inv_map[label] for label in testLabels]

print(trainLabelNums)
# Out:
# ['19', '5', '5', '7', '7', '11', '12', '15', '4', '15', '18', '3', '11', '6', '3', '15', '8', '4', '5', '13', '4', '4', '1', '16', '8', '18', '8', '8', '19', '10', '1', '7', '16', '1', '4', '5', '7', '7', '24', '4', '19', '17', '16', '6', '19', '16', '19', '15', '25', '8', '11', '1', '23', '2', '8', '8', '13', '15', '17', '1', '17', '1', '10', '7', '8', '18', '1', '19', '15', '11', '17', '5', '11', '16', '17', '6', '16', '10', '15', '10', '20', '11', '19', '13', '4', '10', '4', '10', '18', '11', '6', '10', '8', '6', '18', '12', '5', '20', '1', '10', '7', '17', '19', '7', '12', '1', '24', '11', '16', '11', '2', '4', '13', '6', '8', '8', '4', '18', '3', '2', '7', '7', '11', '18', '5', '10', '10', '11', '11', '3', '7', '17', '11', '3', '20', '15', '4', '1', '5', '20', '6', '7', '2', '20', '18', '3', '2', '24', '19', '2', '10', '18', '7', '24', '16', '8', '3', '13', '5', '6', '7', '17', '4', '16', '5', '2', '7', '17', '15', '4', '12', '18', '11', '4', '8', '10', '2', '16', '5', '20', '1', '5', '4', '18', '2', '5', '5', '19', '1', '10', '15', '1', '10', '13', '2', '25', '6', '11', '16', '8', '7', '5', '10', '7', '15', '10', '20', '19', '24', '2', '8', '3', '4', '7', '10', '13', '4', '24', '8', '4', '25', '15', '11', '25', '6', '19', '18', '15', '23', '3', '12', '7', '24', '7', '25', '5', '11', '2', '20', '1', '5', '25', '3', '16', '20', '3', '13', '7', '8', '20', '18', '13', '8', '10', '8', '15', '18', '11', '13', '7', '5', '16', '4', '2', '11', '15', '19', '4', '16', '6', '17', '18', '15', '6', '18', '5', '15', '20', '5', '8', '4', '2', '12', '5', '3', '6', '8', '13', '16', '20', '10', '2', '2', '8', '1', '13', '16', '19', '19', '10', '2', '2', '5', '25', '23', '13', '10', '6', '2', '2', '8', '18', '4', '3', '2', '3', '5', '16', '7', '2', '18', '18', '7', '18', '1', '11', '7', '13', '8', '11', '19', '6', '6', '5', '2', '8', '1', '7', '15', '2', '11', '5', '8', '1', '7', '5', '15', '13', '2', '8', '11', '23', '5', '3', '13', '11', '19', '4', '1', '25', '18', '2', '6', '5', '3', '11', '17', '1', '11', '3', '3', '24', '5', '16', '7', '7', '4', '13', '25', '3', '10', '5', '11', '6', '18', '6', '23', '13', '12', '7', '1', '6', '1', '4', '5', '4', '4', '11', '1', '23', '5', '12', '3', '4', '2', '1', '24', '19', '8', '18', '18', '7', '15', '11', '17', '20', '11', '3', '8', '15', '17', '6', '1', '17', '11', '23', '16', '17', '17', '4', '15', '7', '8', '6', '13', '8', '17', '13', '5', '13', '2', '2', '19', '19', '11', '6', '6', '20', '13', '12', '6', '5', '10', '10', '5', '3', '12', '2', '11', '24', '1', '11', '24', '2', '13', '7', '2', '2', '3', '3', '6', '8', '17', '17', '16', '17', '6', '3', '6', '18', '11', '15', '1', '11', '25', '1', '11', '2', '17', '25', '1', '2', '12', '13', '15', '16', '8', '16', '10', '6', '4', '16', '13', '19', '19', '18', '5', '1', '24', '10', '10', '17', '4', '17', '11', '15', '16', '19', '11', '2', '16', '7', '6', '12', '20', '4', '5', '8', '4', '11', '11', '18', '3', '23', '7', '18', '7', '5', '2', '1', '8', '8', '18', '3', '7', '13', '5', '5', '11', '25', '16', '10', '12', '8', '11', '3', '16', '13', '17', '6', '4', '5', '6', '6', '11', '4', '17', '19', '19', '2', '20', '19', '8', '15', '5', '7', '6', '24', '10', '17', '15', '23', '11', '3', '4', '24', '11', '4', '7', '11', '1', '20', '7', '8', '17', '23', '1', '2', '2', '4', '4', '17', '16', '25', '12', '7', '5', '13', '3', '24', '20', '4', '4', '2', '2', '2', '13', '8', '2', '15', '6', '1', '7', '13', '15', '4', '4', '7', '3', '1', '5', '3', '8', '11', '12', '10', '6', '16', '4', '11', '20', '11', '4', '8', '17', '25', '11', '6', '18', '8', '15', '10', '7', '1', '18', '7', '3', '11', '20', '15', '3', '17', '11', '3', '11', '2', '11', '2', '8', '4', '11', '20', '2', '16', '19', '20', '15', '10', '4', '15', '17', '13', '15', '12', '2', '4', '8', '2', '11', '4', '6', '2', '1', '13', '11', '11', '6', '3', '5', '18', '18', '2', '7', '15', '6', '3', '1', '11', '5', '5', '1', '4', '11', '5', '5', '18', '24', '19', '3', '16', '2', '17', '3', '4', '8', '12', '20', ...

# %%
clf = SVC(C=14000)
clf.fit(X_train, trainLabelNums)
# Out:
# SVC(C=14000)

# %%
ypred_train = clf.predict(X_train)
ypred_test = clf.predict(X_test)

# %%
print("LINEAR REGRESSION")
print("Train Score: ")
print(r2_score(trainLabelNums, ypred_train))
print("Test Score: ")
print(r2_score(testLabelNums, ypred_test))
# Out:
# LINEAR REGRESSION
# Train Score:
# 0.998939696975796
# Test Score:
# 0.9798880225457217
# /opt/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:63: FutureWarning: Arrays of bytes/strings is being converted to decimal numbers if dtype='numeric'. This behavior is deprecated in 0.24 and will be removed in 1.1 (renaming of 0.26). Please convert your data to numeric values explicitly instead.
#   return f(*args, **kwargs)
# /opt/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:63: FutureWarning: Arrays of bytes/strings is being converted to decimal numbers if dtype='numeric'. This behavior is deprecated in 0.24 and will be removed in 1.1 (renaming of 0.26). Please convert your data to numeric values explicitly instead.
#   return f(*args, **kwargs)
# /opt/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:63: FutureWarning: Arrays of bytes/strings is being converted to decimal numbers if dtype='numeric'. This behavior is deprecated in 0.24 and will be removed in 1.1 (renaming of 0.26). Please convert your data to numeric values explicitly instead.
#   return f(*args, **kwargs)
# /opt/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:63: FutureWarning: Arrays of bytes/strings is being converted to decimal numbers if dtype='numeric'. This behavior is deprecated in 0.24 and will be removed in 1.1 (renaming of 0.26). Please convert your data to numeric values explicitly instead.
#   return f(*args, **kwargs)

# %%
import pickle

# save the model to disk
filename = 'classification_model.sav'
pickle.dump(clf, open(filename, 'wb'))

# %%
# load the model from disk
loaded_model = pickle.load(open(filename, 'rb'))
result = loaded_model.score(X_test, testLabelNums)
print(result)
# Out:
# 0.984015984015984

# %% [markdown]
# # Testing integration with recommend.py pipeline

# %%
import argparse
import logging
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
from spotipy.oauth2 import SpotifyOAuth
import math
from sklearn.linear_model import LinearRegression
from os.path import exists
import re
import tsfresh
from tsfresh.feature_extraction import MinimalFCParameters

#Initialize Spotify Client
logger = logging.getLogger()
logging.basicConfig()
CLIENT_ID="9793440f0a5047c59c70bcfcf91ad589"
CLIENT_SECRET= "b66dc3a5f9f34207bebee32a25745368"
REDIRECT_URL="http://localhost/"
client_credentials_manager = SpotifyClientCredentials(client_id = CLIENT_ID, client_secret = CLIENT_SECRET)
oAuth = SpotifyOAuth(client_id = CLIENT_ID, client_secret = CLIENT_SECRET, redirect_uri = REDIRECT_URL, scope = 'user-modify-playback-state')
sp = spotipy.Spotify(auth_manager =oAuth)

song_artist_pairs = {
    '1':('thats_what_i_like','bruno_mars'),
    '2':('humble','kendrick_lamar'),
    '3':('skeletons','keshi'),
    '4':('slow_dancing_in_the_dark','joji'),
    '5':('lite_spots','kaytranada'),
    '6':('woman','doja_cat'),
    '7':('get_up','ciara'),
    '8':('throwin_elbows','excision'),
    '9':('power','little mix'),
    '10':('peaches','justin_bieber'),
    '11':('knife_talk','drake'),
    '12':('fool_around','yas'),
    '13':('levitating','dua_lipa'),
    '14':('feed_the_fire','lucky_daye'),
    '15':('easily','bruno_major'),
    '16':('good_4_u','olivia_rodrigo'),
    '17':('all_i_wanna_do','jay_park'),
    '18':('sad_girlz_luv_money','amaarae'),
    '19':('tik_tok','kesha'),
    '20':('ymca','village_people'),
    '21':('intuition_interlude','jamie_foxx'),
    '22':('kilby_girl','the_backseat_lovers'),
    '23':('a_thousand_miles','vanessa_carlton'),
    '24':('jupiter_love', 'trey_songz'),
    '25':('kilby_girl', 'backseat_lovers')
}

def get_song(name_song, name_artist):
    results = sp.search(q=name_song + ' '+name_artist, type='track')
    items = results['tracks']['items']
    if len(items) > 0:
        return items[0]
    else:
        return None

def show_recommendations_for_song(song):
    results = sp.recommendations(seed_tracks=[song['id']], limit=5)
    print("Recommendations:")
    for track in results['tracks']:
        print("TRACK: ",track['name'], " - ",track['artists'][0]['name'])
        sp.add_to_queue(track['uri'])

def split_ele(x):
    a = np.array(re.findall(r"[-+]?\d*\.?\d+|[-+]?\d+", x))
    return a.astype(float)

def preprocess(file_name):
    num_features = 10
    num_nodes = 14
    num_samples = 10
    pose_landmark_subset = ['LEFT_EYE_OUTER', 'RIGHT_EYE_OUTER', 'LEFT_SHOULDER', 'RIGHT_SHOULDER', 'LEFT_ELBOW', 'RIGHT_ELBOW', 'LEFT_WRIST', 'RIGHT_WRIST', 'LEFT_HIP', 'RIGHT_HIP','LEFT_KNEE', 'RIGHT_KNEE', 'LEFT_ANKLE', 'RIGHT_ANKLE']
    df_columns = ['LEFT_EYE_OUTER_POS', 'LEFT_EYE_OUTER_DIST', 'RIGHT_EYE_OUTER_POS', 'RIGHT_EYE_OUTER_DIST', 'LEFT_SHOULDER_POS', 'LEFT_SHOULDER_DIST', 'RIGHT_SHOULDER_POS', 'RIGHT_SHOULDER_DIST', 'LEFT_ELBOW_POS', 'LEFT_ELBOW_DIST', 'RIGHT_ELBOW_POS', 'RIGHT_ELBOW_DIST', 'LEFT_WRIST_POS', 'LEFT_WRIST_DIST', 'RIGHT_WRIST_POS', 'RIGHT_WRIST_DIST', 'LEFT_HIP_POS', 'LEFT_HIP_DIST', 'RIGHT_HIP_POS', 'RIGHT_HIP_DIST', 'LEFT_KNEE_POS', 'LEFT_KNEE_DIST', 'RIGHT_KNEE_POS', 'RIGHT_KNEE_DIST', 'LEFT_ANKLE_POS', 'LEFT_ANKLE_DIST', 'RIGHT_ANKLE_POS', 'RIGHT_ANKLE_DIST']
    df = pd.read_csv(file_name, sep = ',', usecols=[4, 7, 12, 13, 14, 15, 16, 17, 24, 25, 26, 27, 28, 29])
    splitDf = df
    x_data = pd.DataFrame(columns=df_columns, index=range(len(df)))
    y_data = pd.DataFrame(columns=df_columns, index=range(len(df)))
    for node in pose_landmark_subset:
        curr = df[node]
        vals = [split_ele(x) for x in curr]
        for row in range(len(vals)):
            colname_pos = node + "_POS"
            colname_dist = node + "_DIST"
            if(row == 0):
                x_data[colname_dist][row] = 0
                y_data[colname_dist][row] = 0
            else:
                x_data[colname_dist][row] = vals[row][0] - vals[row-1][0]
                y_data[colname_dist][row] = vals[row][1] - vals[row-1][1]
            x_data[colname_pos][row] = vals[row][0]
            y_data[colname_pos][row] = vals[row][1]
    return [x_data, y_data]

def parse(x_data, y_data):
    num_features = 10
    num_nodes = 14
    num_samples = 10
    df_columns = ['LEFT_EYE_OUTER_POS', 'LEFT_EYE_OUTER_DIST', 'RIGHT_EYE_OUTER_POS', 'RIGHT_EYE_OUTER_DIST', 'LEFT_SHOULDER_POS', 'LEFT_SHOULDER_DIST', 'RIGHT_SHOULDER_POS', 'RIGHT_SHOULDER_DIST', 'LEFT_ELBOW_POS', 'LEFT_ELBOW_DIST', 'RIGHT_ELBOW_POS', 'RIGHT_ELBOW_DIST', 'LEFT_WRIST_POS', 'LEFT_WRIST_DIST', 'RIGHT_WRIST_POS', 'RIGHT_WRIST_DIST', 'LEFT_HIP_POS', 'LEFT_HIP_DIST', 'RIGHT_HIP_POS', 'RIGHT_HIP_DIST', 'LEFT_KNEE_POS', 'LEFT_KNEE_DIST', 'RIGHT_KNEE_POS', 'RIGHT_KNEE_DIST', 'LEFT_ANKLE_POS', 'LEFT_ANKLE_DIST', 'RIGHT_ANKLE_POS', 'RIGHT_ANKLE_DIST']
    curr_extracted_vector = pd.DataFrame()
    for col in df_columns:
        col_x = x_data[col]
        col_y = y_data[col]
        xname = col + "_x"
        yname = col + "_y"
        settings = {
            xname: {
                "kurtosis": None, 
                "standard_deviation": None, 
                "autocorrelation": [{"lag": 10}],
                "approximate_entropy": [{"m": 20, "r": 0.05}],
                "c3": [{"lag": 10}],
                "cid_ce": [{"normalize": True}]
            }, 
            yname: {
                "kurtosis": None, 
                "standard_deviation": None, 
                "autocorrelation": [{"lag": 10}],
                "approximate_entropy": [{"m": 20, "r": 0.05}],
                "c3": [{"lag": 10}],
                "cid_ce": [{"normalize": True}]
            }
        }
        comb = pd.DataFrame(data=[col_x, col_y], index=[xname, yname]).T
        comb.rename_axis("time")
        comb["id"] = 1
        comb["time"] = comb.index
        curr_extracted = tsfresh.extract_features(comb, column_id = "id", column_sort="time", column_kind=None, column_value=None, kind_to_fc_parameters=settings, disable_progressbar=True)
        curr_extracted_vector = pd.concat([curr_extracted_vector, curr_extracted], axis=1)
    return curr_extracted_vector

# %%
[x_data, y_data] = preprocess("data/9_ymca_village_people.csv")
extracted_features = parse(x_data, y_data)
print(extracted_features)
# Out:
#    LEFT_EYE_OUTER_POS_x__kurtosis  LEFT_EYE_OUTER_POS_x__standard_deviation  \
# 1                       -1.214993                                 30.415348
#
#    LEFT_EYE_OUTER_POS_x__autocorrelation__lag_10  \
# 1                                       0.453837
#
#    LEFT_EYE_OUTER_POS_x__approximate_entropy__m_20__r_0.05  \
# 1                                            0.00545
#
#    LEFT_EYE_OUTER_POS_x__c3__lag_10  \
# 1                      2.222940e+07
#
#    LEFT_EYE_OUTER_POS_x__cid_ce__normalize_True  \
# 1                                      2.912683
#
#    LEFT_EYE_OUTER_POS_y__kurtosis  LEFT_EYE_OUTER_POS_y__standard_deviation  \
# 1                        6.402711                                 21.413296
#
#    LEFT_EYE_OUTER_POS_y__autocorrelation__lag_10  \
# 1                                      -0.189787
#
#    LEFT_EYE_OUTER_POS_y__approximate_entropy__m_20__r_0.05  ...  \
# 1                                            0.00545        ...
#
#    RIGHT_ANKLE_DIST_x__autocorrelation__lag_10  \
# 1                                    -0.144835
#
#    RIGHT_ANKLE_DIST_x__approximate_entropy__m_20__r_0.05  \
# 1                                           0.009845
#
#    RIGHT_ANKLE_DIST_x__c3__lag_10  RIGHT_ANKLE_DIST_x__cid_ce__normalize_True  \
# 1                      -31.382525                                   17.414563
#
#    RIGHT_ANKLE_DIST_y__kurtosis  RIGHT_ANKLE_DIST_y__standard_deviation  \
# 1                     39.869183                                8.949133
#
#    RIGHT_ANKLE_DIST_y__autocorrelation__lag_10  \
# 1                                     -0.00865
#
#    RIGHT_ANKLE_DIST_y__approximate_entropy__m_20__r_0.05  \
# 1                                            0.00545
#
#    RIGHT_ANKLE_DIST_y__c3__lag_10  RIGHT_ANKLE_DIST_y__cid_ce__normalize_True
# 1                        4.399457                                   18.350721
#
# [1 rows x 336 columns]

# %%
def generate_classification_prediction(data):
    data = data.to_numpy()
    
    filename = 'classification_model.sav'
    model = pickle.load(open(filename, 'rb'))
    
    prediction = model.predict(data)
    print(prediction)
    artist_song = song_artist_pairs[prediction[0]]
    song = get_song(artist_song[0], artist_song[1])

    show_recommendations_for_song(song)
    return

predicted_song_number = generate_classification_prediction(extracted_features)
# Out:
# ['16']
# Recommendations:
# TRACK:  Baby, I'm Jealous (feat. Doja Cat)  -  Bebe Rexha
# TRACK:  Formula  -  Labrinth
# TRACK:  Solar Power  -  Lorde
# TRACK:  Body  -  Megan Thee Stallion
# TRACK:  Up  -  Cardi B
