# %%
import pandas as pd
import numpy as np


df = pd.read_csv('joint_data/humble.csv')

# %%
class Point(object):

    def __init__(self):
        self.x = 0
        self.y = 0
        self.z = 0

def distance(point1, point2):
  dx = point1.x - point2.x
  dy = point1.y - point2.y
  dz = point1.z - point2.z
  return math.sqrt(dx**2 + dy**2 + dz**2)

# %%
import re
from shapely.geometry import Point

def convert_to_points(df):
  for rowIndex, row in df.iterrows(): #iterate over rows
      for columnIndex, value in row.items():
          if isinstance(value, str):
            value = re.split('; |x: |y:|z: |\n',value)
            if len(value) >= 6:
              point = Point(float(value[1]), float(value[3]), float(value[5]))
              
              df.loc[rowIndex, columnIndex] = point

convert_to_points(df)
df.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/managers.py:409: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   applied = getattr(b, f)(**kwargs)
#    Unnamed: 0  ... PINKY_TIP2
# 0           0  ...        NaN
# 1           1  ...        NaN
# 2           2  ...        NaN
# 3           3  ...        NaN
# 4           4  ...        NaN
#
# [5 rows x 76 columns]
